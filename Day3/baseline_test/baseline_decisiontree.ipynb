# %%
import pandas as pd
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
# Out:
# /tmp/ipykernel_202674/3824362204.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data_path = "/home/workspace/LGamiers/"
df_train = pd.read_csv(data_path + "train.csv") # 학습용 데이터
df_test = pd.read_csv(data_path + "submission.csv")

# %%
def label_encoding(series: pd.Series) -> pd.Series:
    """범주형 데이터를 시리즈 형태로 받아 숫자형 데이터로 변환합니다."""

    my_dict = {}

    # 모든 요소를 문자열로 변환
    series = series.astype(str)
    # unique value 찾고 아스키코드 기준으로 sort
 
    # my_dict을 통해 unique value에 대응하는 label 생성 
    for idx, value in enumerate(sorted(series.unique())):
        my_dict[value] = idx
    # my_dict의 index와 매치되는 series값을 my_dict의 value로 변환한다.
    series = series.map(my_dict)

    return series

# %%
# 레이블 인코딩할 칼럼들
label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_country.1",
    "customer_position",
    "response_corporate",
    "expected_timeline",
]

df_all = pd.concat([df_train[label_columns], df_test[label_columns]])

for col in label_columns:
    df_all[col] = label_encoding(df_all[col])
# Out:
# ['Quotation or purchase consultation' 'Product Information'
#  'Quotation or Purchase Consultation' 'Other'
#  'Usage or technical consultation' 'Trainings' 'Services' 'Sales Inquiry'
#  'Etc.' 'Technical Support' 'Usage or Technical Consultation'
#  'Technical Consultation' 'Request for Partnership' nan 'sales'
#  'technical' 'usage or technical consultation'
#  'usage_or_technical_consultation' 'other'
#  'quotation_or_purchase_consultation' 'other_' 'Request a Demo'
#  'Request for Distributorship' 'Request for quotation or purchase'
#  'Request for technical consulting' '(Select ID_Needs)' 'One Quick:Flex'
#  'AIO' 'Needs' 'Purchase' 'technical_consultation' 'Customer Suggestions'
#  'Event Inquiry' 'Others' 'OEM/ODM Request' 'Hospital TV' 'others'
#  'i want to know the details about it' 'EDUCATIONAL EQUIPMENTS'
#  'Digital platform' 'TV interactive' 'teach' 'Display Textbook and photos'
#  'High inch 86 / 98 or 110' 'quotation_' 'Purchase or Quotation'
#  'display product' 'first Info and pricing' 'Sales inquiry'
#  'estoy buscando para Ecuador este producto LG MAGNIT micro LED, para un cliente de 138 pulgadas, con envió marítimo.'
#  'Hola me pueden cotizar 19 pantallas interactivas de 100 pulgadas entregadas en Guayaquil -Ecuador.'
#  'window facing product'
#  'Vui lòng báo giá giúp mình sản phẩm đo thân nhiệt Xin cảm ơn'
#  'Probeam precio' 'Quotation or Purchase consultation' 'Hotel TV products'
#  'Pantallas Interactivas para Clinicas'
#  'Solicito apoyo para realizar cotizacion de los dispositivos que ofrecen en la solución\xa0One Quick:\xa0'
#  'Intégrateur historique du George V' 'ETC.' 'IDB' 'Not specified'
#  'for school' 'Media Inquiry' 'LED Signage' 'Standalone' 'Video Wall'
#  'Toi muon tim hieu thong tin ky thuat, gia ca cua sp de su dung'
#  'tôi cần tham khảo giá và giải pháp từ LG'
#  'Preciso de um monitor médico para radiografia convencional e tomogrtafia.'
#  'VRF' 'Evento_SdelEstero']
# ['#314 G. Araneta Ave. Quezon City NCR //Philippines', '#314 G. Araneta Ave. Quezon City NCR /Caloocan City/Philippines', '#7/2 Jaishree Plaza Advaitha Ashram Road /Salem/', '-   / AL / United States', '.Mpilo and Pioneer Road Maseru  /Maseru/', '/\tWest Drayton , Harmondsworth/United Kingdom', '/  /', '/  / Afghanistan', '/  / Argentina', '/  / Australia', '/  / Austria', '/  / Brazil', '/  / Canada', '/  / Chile', '/  / China', '/  / Colombia', '/  / Costa Rica', '/  / Dominican Republic', '/  / Ecuador', '/  / Egypt', '/  / El Salvador', '/  / Estonia', '/  / France', '/  / Georgia', '/  / Germany', '/  / Greece', '/  / Hong Kong', '/  /
/ Philippines', '/ Antofagasta / Chile', '/ Anápolis / Brazil', '/ Aparecida - SP / Brazil', '/ Aquiraz / Brazil', '/ Ara / India', '/ Aracaju - Sergipe / Brazil', '/ Aracaju - se / Brazil', '/ Aracaju / Brazil', '/ Araras / Brazil', '/ Araçariguama / Brazil', '/ Areraj / India', '/ Argao Cebu city / Philippines', '/ Arica / Chile', '/ Armenia, Quindío / Colombia', '/ Arujá / Brazil', '/ Asansol / India', '/ Ashford / United Kingdom', '/ Assam / India', '/ Asuncion / Brazil', '/ Asyut / Eg ...
# ['Advertising', 'Aerospace', 'Agriculture', 'Airline', 'Airport / Airfield / Helipad', 'Apartment', 'Banking', 'Bookstore', 'Botanical Garden / Green House', 'Broadcasting & Media', 'Bus Terminal', 'CVS (Convenience Store)', 'Car Dealership', 'Casino Resort', 'Chemical Factory / Plant', 'Cinema /Theater', 'Clinic', 'Construction', 'Consulting', 'Cosmetics', 'Cruise', 'Developer/Property', 'Distribution Center', 'Dormitory', 'Duty Free Shop', 'Electronics & Telco', 'Energy', 'Energy Storage & Saving', 'Engineering', 'Entertainment', 'Exhibition / Convention Center', 'F&B(Food and Beverage)', 'Fashion', 'Finance', 'Fitness', 'Gas Station', 'General Government Office', 'General Hospital', 'Healthcare', 'Higher Education (College & University)', 'Holdings', 'Hospital', 'Hotel', 'Hyper Market & Grocery', 'IT/Software', 'Institute & Academy', 'Insurance', 'Investment', 'K12 Kindergarten & Schools', 'LTC(Long-Term Care)', 'Law Firm', 'Logistics', 'Luxury(Watch/Jewelry Shop)', 'Manufacturing', 'Manufacturing Factory / Plant', 'Military', 'Mining', 'Mixed-use (Multi Complex)', 'Museum / Gallery', 'Network/Cabling', 'Officetel', 'Other Stores', 'Others', 'Outdoor Advertisement', 'Pharmaceutical', 'Pharmaceutical Factory', 'Pharmacy', 'Police / Fire station', 'Power Plant', 'QSR(Quick Service Restaurant)', 'Railway & Metro Station', 'Real-Estate Agency', 'Religious Facility', 'Renewable Energy', 'Resort', 'Restaurant', 'Sea Passenger Terminal / Port', 'Shopping Mall', 'Sports', 'Sports Entertainment', 'Telecom Base Station / Data, Call', 'Telecommunication', 'Townhouse', 'Travel Agency', 'Villa / Single-Family Home', 'Welfare Facilities', 'nan']
# ['corporate / office', 'education', 'factory', 'government department', 'hospital & health care', 'hotel & accommodation', 'nan', 'power plant / renewable energy', 'public facility', 'residential (home)', 'retail', 'special purpose', 'transportation']
# ['AS', 'CM', 'ID', 'IT', 'Solution']
# ['Administrator', 'Architect/Consultant', 'Channel Partner', 'Commercial end-user', 'Consultant', 'Corporate', 'Dealer/Distributor', 'Developer', 'Distributor', 'End Customer', 'End-Customer', 'End-user', 'Engineer', 'Etc.', 'HVAC Engineer', 'Home Owner', 'Homeowner', 'Installer', 'Installer/Contractor', 'Interior Designer', 'Manager / Director', 'Other', 'Others', 'Reseller', 'Service Partner', 'Software / Solution Provider', 'Software/Solution Provider', 'Solution Eco-Partner', 'Specifier / Influencer', 'Specifier/ Influencer', 'System Integrator', 'Technical Assistant', 'Technician', 'nan']
# ['Enterprise', 'SMB']
# ['3d/vfx art', '5% of hotel needs', 'a/v project manager', 'account exec/manager', 'account management', 'accounting', 'accounts payable', 'admin', 'admin assistant', 'administración', 'administration', 'administrative', 'administrative assistant', 'adminisztráció', 'advertising', 'advertising and promotions team', 'altro', 'amministrativo', 'appliance specialist', 'application development', 'architect', 'architect ass interiores', 'architect/owner', 'arquitecto/consultor', 'art and design', 'art installation', 'arte y diseño', 'arte_e_design', 'artist, lead on equipment selection', 'arts and design', 'arts_and_design', 'asking for quote for client', 'asset management', 'assist in serving food', 'associate/analyst', 'authorize (you are responsible for making the final decision)', 'autres', 'av estimator', 'av project manager', 'av tech', 'av technician', 'bidder', 'broadcasting & media', 'building owner', 'business development', 'business owner', 'business_development', 'buyer', 'buyer, coordinating', 'c-level executive', 'car dealership', 'cctv monetoring', 'cctv view', 'ceo', 'ceo/founder', 'change tv', 'chef', 'chief', 'chief eng.', 'chief engineer', 'chief of engineering', 'chirurgien', 'cintractor', 'cirugano', 'cliente final', 'clinic', 'clinical specialist', 'cloud / mobility', 'collaboration & web apps', 'colorist', 'comanager', 'commander', 'community and social services', 'community theater', 'community_and_social_services', 'component of video wall', 'computing & it', 'conference room', 'conference table', 'construction manager', 'consultant', 'consultant / purchaser', 'consultant,cabinet fabricator', 'consultent', 'consulting', 'content creation, eq consultant', 'contractor', 'contractor/owner', 'contributor', 'coo', 'coordinator', 'corporate / office', 'correspondence', 'costar av team', 'creative director', 'curation', 'customer experience', 'decider', 'decision maker', 'department secretary', 'deputy cio', 'design', 'design and install', 'design and installation company', 'design and provide equipment', 'design consultant', 'design engineer', 'design/build', 'design/decision maker', 'design/install/training/support', 'design/purchaser', 'designer', 'designer purchaser', 'designer, creative technologist', 'designer, producer', 'designer/ engineer', 'designer/ project manager', 'designer/installer', 'designer/pm/gc', 'designere / budget', 'designers', 'details send', 'developer', 'developer/property', 'development coordinator/procurement', 'digital display vs signage need', 'digital project manager', 'digital signage', 'directeur technique', 'director', 'director comercial', 'director it', 'director of engineering', 'director of finance', 'director of it', 'director of lodging', 'director of operations', 'director purchaser', 'director,it', 'display', 'display our products', 'display screen', 'display screen from control', 'distribuidor', 'distributor', 'distributor quotation', 'doctor', 'drop, purchase maxhub', 'education', 'educator', 'egyéb', 'electrical contractor', 'electronics & telco', 'electronics evaluator', 'elevator company', 'emerging technology / innovation', 'end user', 'energy', 'engagement executive', 'engineer', 'engineering', 'engineering & technical', 'engineering & technical executive', 'engineering director', 'engineering, design, and install', 'enterprise resource planning', 'entrepreneurship', 'entry level', 'equipment and app provider', 'equipment custodian', 'equipment planner', 'equipment selection', 'estimator', 'event marketing', 'execution', 'executive', 'exhibition / convention center', 'f&b director for bicycle casino', 'facilitator', 'facilitator installation services', 'facilities', 'facilities and operations', 'facility administrator', 'facility manager', 'fashion', 'federal government contractor', 'field / outside sales', 'field marketing', 'film production', 'final approval', 'finance', 'finance executive', 'finanzas', 'finanzen', 'fixing tv', 'following up', 'for confrence', 'f ...
# ['(Select ID_Needs)', 'AIO', 'Customer Suggestions', 'Digital platform', 'Display Textbook and photos', 'EDUCATIONAL EQUIPMENTS', 'ETC.', 'Etc.', 'Event Inquiry', 'Evento_SdelEstero', 'High inch 86 / 98 or 110', 'Hola me pueden cotizar 19 pantallas interactivas de 100 pulgadas entregadas en Guayaquil -Ecuador.', 'Hospital TV', 'Hotel TV products', 'IDB', 'Intégrateur historique du George V', 'LED Signage', 'Media Inquiry', 'Needs', 'Not specified', 'OEM/ODM Request', 'One Quick:Flex', 'Other', 'Others', 'Pantallas Interactivas para Clinicas', 'Preciso de um monitor médico para radiografia convencional e tomogrtafia.', 'Probeam precio', 'Product Information', 'Purchase', 'Purchase or Quotation', 'Quotation or Purchase Consultation', 'Quotation or Purchase consultation', 'Quotation or purchase consultation', 'Request a Demo', 'Request for Distributorship', 'Request for Partnership', 'Request for quotation or purchase', 'Request for technical consulting', 'Sales Inquiry', 'Sales inquiry', 'Services', 'Solicito apoyo para realizar cotizacion de los dispositivos que ofrecen en la solución\xa0One Quick:\xa0', 'Standalone', 'TV interactive', 'Technical Consultation', 'Technical Support', 'Toi muon tim hieu thong tin ky thuat, gia ca cua sp de su dung', 'Trainings', 'Usage or Technical Consultation', 'Usage or technical consultation', 'VRF', 'Video Wall', 'Vui lòng báo giá giúp mình sản phẩm đo thân nhiệt Xin cảm ơn', 'display product', 'estoy buscando para Ecuador este producto LG MAGNIT micro LED, para un cliente de 138 pulgadas, con envió marítimo.', 'first Info and pricing', 'for school', 'i want to know the details about it', 'nan', 'other', 'other_', 'others', 'quotation_', 'quotation_or_purchase_consultation', 'sales', 'teach', 'technical', 'technical_consultation', 'tôi cần tham khảo giá và giải pháp từ LG', 'usage or technical consultation', 'usage_or_technical_consultation', 'window facing product']
# ['110 + video wall', '28mq780', '32 / 43 pol', '32 pol', '32lq621cbsb.awz', '43 pol', '43uh5f-h.awzm', '43uq751c0sb.bwz', '43uq751c0sf.bwz', '43us660h (na)', '43us660h0sd.awz', '49uh / 49xf', '49vl5f', '49vl5g-m', '49vl5g-m.awzm', '50uq801c0sb.bwz', '50us660h0sd.bwz', '55svh7f-a', '55tc3d', '55uq801c0sb.bwz', '55us660h0sd.bwz', '55vm5e-a', '55vm5j-h', '86uh5f', '98uh5e', 'a definir', 'a thermodynamic water heater', 'ac rumah', 'accessories', 'ahu', 'aio', 'aio | one quick', 'aircare,built-in/cooking', 'aircare,mobile', 'aircare,water care', 'aire acondicionado residencial', 'all lg vrf systems', 'allinone_rmk', 'aquecimento', 'ar condicionado residencial', 'autre', 'bu50nst', 'cac', 'calefacción', 'chiller', 'chiller,aircare', 'chiller,dryer', 'chiller,refrigerator', 'chiller,tv', 'chiller,water care', 'chiller/enfriadoras', 'climatiseur résidentiel', 'cloud device', 'collaboration displays', 'comercial tv', 'commercial display', 'commercial tv', 'commercial tv,audio/video', 'commercial tv,monior/monitor tv', 'commercial tv,projector', 'commercial tv,robot', 'commercial tv,solar', 'commercial tv,solar,ess,monior/monitor tv,pc,projector,robot,system ac,ems,rac,chiller,refrigerator,', 'commercial tv,solar,ess,projector,system ac,tv,washing machine,home beauty,audio/video', 'commercial tv,tv', 'commercial tv,water care', 'computer monitors', 'control', 'corpouh5f', 'corpuh5f-', 'ctv', 'digital signage', 'digital signage or commercial tvs', 'dryer,chiller', 'education createboard', 'ems,audio/video', 'energy storage system', 'error', 'ess', 'ess,chiller', 'essential series', 'etc.', 'fhd series', 'gsca046', 'gscd046', 'gscd100', 'heating', 'high brightness', 'high brightness signage', 'high inch 86 / 98 or 110', 'hospital tv', 'hospitality', 'hotel tv', 'hoteleria_us670h', 'htv', 'id', 'idb', 'information display,monitor', 'inne', 'interactive digital board', 'interactive signage', 'isıtma', 'khác', 'kimatyzacja vrf', 'klimatyzacja multi-split', 'laec015', 'laec015-gn.awz', 'laec15', 'lainnya', 'laptop', 'leadallin', 'led', 'led 70m2', 'led aio 136', 'led cinema', 'led signage', 'led 顯示屏', 'ledallinone', 'lg customer care program', 'lg home bliss air solution', 'lg led bloc', 'lg magnit', 'lg one:quick', 'lg one:quick series', 'lg paradise air solution', 'lg salang air solution for dream homes', 'lsca039', 'medical display', 'medical displays', 'medical monitor', 'medical monitors', 'medical- surgical', 'meeting & screen sharedirect view leddirect view led', 'mobile,audio/video', 'monior/monitor tv,audio/video', 'monior/monitor tv,chiller', 'monior/monitor tv,pc', 'monior/monitor tv,projector,audio/video', 'monior/monitor tv,refrigerator', 'monior/monitor tv,refrigerator,audio/video', 'monior/monitor tv,system ac,tv,pc,refrigerator,water care,solar,washing machine,mobile,chiller,built', 'monior/monitor tv,system ac,tv,refrigerator,washing machine,dryer,built-in/cooking', 'monior/monitor tv,tv', 'monior/monitor tv,tv,commercial tv,pc,refrigerator,solar,rac,washing machine,mobile,ess,audio/video', 'monitor', 'monitor & pc', 'monitor signage,audio/video', 'monitor signage,commercial tv', 'monitor signage,commercial tv,audio/video', 'monitor signage,commercial tv,monior/monitor tv', 'monitor signage,commercial tv,monior/monitor tv,audio/video', 'monitor signage,commercial tv,monior/monitor tv,pc,projector,tv,audio/video', 'monitor signage,commercial tv,monior/monitor tv,pc,tv,home beauty,audio/video', 'monitor signage,commercial tv,monior/monitor tv,projector,tv', 'monitor signage,commercial tv,monior/monitor tv,tv', 'monitor signage,commercial tv,solar,ess', 'monitor signage,commercial tv,solar,ess,monior/monitor tv,pc', 'monitor signage,commercial tv,solar,ess,monior/monitor tv,pc,projector,robot,system ac,ems,rac,chill', 'monitor signage,commercial tv,solar,pc,projector,system ac,ems,rac,chiller,refrigerator,washing mach', 'monitor signage,commercial tv,solar,projector,robot,chiller,refrigerator,built-in/cooking,water care', 'monit ...
# ['0.44mm EVEN BEZEL VIDEO WALL', '0.44mm Even Bezel Video Wall', '0.9mm Even Bezel Video Wall', '3.0 TR -1 Nos. Cassette', '49', '49" 500 nits FHD Slim Bezel Video Wall', '49VL5J', '4K Laser CineBeam', '4K UHD Hospitality TV with Pro:Centric Direct', '4K UHD Smart TV', '50US660H0SD.BWZ', '55" 500 nits FHD 0.44mm Even Bezel Video Wall', '55" 500 nits FHD Slim Bezel Video Wall', '55" 700 nits FHD 0.44mm Even Bezel Video Wall', '55" 700 nits FHD Slim Bezel Video Wall', '55VH7E-H', '55XS4J-B Écran Vitrine', '65TR3BF', '65TR3DJ', '75UH5C', '75UR640S', 'AIO', 'AN960H Series', 'AR', 'AWHP', 'All Cloud Devices', 'All Laptops', 'All Medical Display', 'All Medical Displays', 'All Monitors', 'All Monitors & PCs', 'All Monitors &PCs', 'All Projectors', 'Budget high for VRF , He will buy the split ac', 'Budget is Higher for VRF', 'Built-in Touch Display', 'Built-in Touch Signage', 'CMS', 'Category', 'Channel Partner done FTS Details in System', 'Chiller', 'CineBeam', 'Cirugia', 'Clinical Displays', 'Clinical Review Monitors', 'Commercial TV', 'Compact Series', 'Createboard', 'Curvable OLED', 'Curvable OLED Sigange', 'Curvable OLED Signage', 'Curvature Calibrator', 'Curved Series', 'DXD', 'Diagnostic Monitor', 'Diagnostic Monitors', 'Diagnostic Monitors\u200b', 'Digital Floor Series', 'Digital Signage or Commercial TVs', 'Digital X-ray Detectors', 'ES961H Series', 'ESS', 'ET961H Series', 'EVR', 'Energy storage, Home automation, PV modules, Solar & water, Solar heating and cooling, hot water, po', 'Ergonomic monitors', 'Essential Commercial TV', 'Essential Commercial TV with 4K Active HDR', 'Essential Commercial TV with Multiple Use', 'Essential Commercial TV with NanoCell Display', 'Essential Series', 'Etc.', 'Eye-level Accessible LED', 'Fine Pitch', 'Fine-pitch Essential Series', 'Flat OLED Sigange', 'Flat OLED Signage', 'Flexible Curved Open Frame', 'Flexible Curved Open Frame OLED Signage', 'Flexible Open Frame OLED', 'Floor LED', 'Floor Stand for One:Quick Flex', 'Full HD Standard Signage', 'Heat Pump Water Heater', 'High Brightness Series', 'High Brightness Video Wall', 'High Haze UHD Signage for Hospitals', 'High-brightness Open-frame Display', 'Hotel', 'Hotel Quick Menu', 'IDB', 'IP Rated Outdoor Series', 'IPS Monitors', 'ISC2', 'Indoor Versatile Series', 'Indoor Versatile Series\xa0', 'Indoor Versatile 系列', 'Interactive', 'Interactive Digital Board', 'LAD033F', 'LAEC015-GN.AWZ', 'LED Cinema', 'LG ConnectedCare', 'LG CreateBoard', 'LG ExtendedCare', 'LG Indoor LED', 'LG LED All-in-One', 'LG LED All-in-One Essential Series', 'LG LED All-in-One LED Essential Series', 'LG LED All-in-One LED Premium Series', 'LG LED All-in-One Premium Series', 'LG LED All-in-One Smart Series', 'LG LED BLOC', 'LG LED Bloc', 'LG LED Curve Series', 'LG MAGNIT', 'LG Miraclass', 'LG Miraclass, 2K Screen', 'LG Miraclass, 4K Resolution, 5m Screen', 'LG Miraclass, 4K Screen', 'LG OPS Player', 'LG One:Quick Flex (Telehealth)', 'LG One:Quick Works (Video Conferencing)', 'LG Self-ordering Kiosk', 'LG Simple Editor', 'LG Smart Cam Pro', 'LG Thermal Sensing Terminal', 'LG UHD Signage for Live TV & Promotion', 'LS341H', 'LT330H Series', 'LT340C Series', 'LT340H Series', 'LT341H Series', 'LT560H Series', 'LT570H Series', 'LT572M Series', 'LT660H Series', 'LT660H 系列', 'LT661H Series', 'LT662M Series', 'LT662M series', 'LU640H Series', 'LU766A Series', 'LV35A Series', 'Laptops', 'Medical Displays- Surgical- ALL', 'Mi', 'Monitor De Diagnostico', 'Monitors for graphics applications & video editing', 'Monitors with USB-C connection', 'Multi V III', 'NanoCell Hospital TV', 'Need Only Hot and Cold Cassette', 'New High Haze UHD Standard Signage', 'No longer available', 'Not available as a split system', 'OLED', 'OLED Monitors', 'OLED Pro', 'OLED Pro Monitor', 'OLED 透明觸控顯示屏', 'One-Quick Share', 'One:Quick', 'One:Quick Flex', 'One:Quick Share', 'One:Quick Works', 'One:Quick Works for Zoom Rooms', 'One:Quick works', 'OneQuick Flex', 'OneQuick Share', 'OneQuick Works', 'Open Frame ...
ic coordinator/ post graduate teacher (accountancy, business studies)/ tgt (ict)', 'academic specialist', 'administrative', 'architect/consultant', 'architecture/consult', 'assistant professor', 'assistant professor of enlish', 'associate professor', 'associate professor in electronics engg', 'associate/analyst', 'asst prof.', 'av management', 'bulgaria', 'business development', 'business development/sales', 'business partner', 'business unit director', 'c-level executive', 'c-levelexecutive', 'career coach', 'cargo', 'ceo/founder', 'ceo/fundador', 'chairman', 'chemistry teacher', 'chief executive officer', 'co-founder', 'commercial consultant', 'commercial end-user', 'consultant', 'consulting', 'customer', 'decision influencer', 'decision maker', 'decision-influencer', 'decision-maker', 'director', 'director cum faculty at gaining apex coaching centre', 'distributor', 'education', 'education professional', 'educator', 'employee', 'end-user', 'engineering', 'english trainer for ielts,toefl,pte,gre,sat exams.', 'entrepreneurship', 'entry level', 'entrylevel', 'exhibition', 'exhibitiontv', 'founder', 'főorvos', 'genel müdür', 'gerente', 'government', 'guest faculty', 'homeowner', 'hon dean', 'hospital', 'installer', 'intern', 'leadership/executive office/owner', 'lider de desarrollo', 'manager', 'manufacturer', 'market intelligence/research', 'math and physics teacher', 'maths lecturer', 'medical device manufacturer', 'medical imaging specialist', 'mindenes', 'neet/ olympiad expert faculty', 'no influence', 'none', 'not applicable', 'operations', 'other', 'other - please specify - cedia association', 'others', 'partner', 'pathologist', 'pgt chemistry', 'pgt physics', 'physics and mathematics teacher', 'physics faculty', 'physics teacher', 'president', 'principal & director', 'principal at oxford integrated pu science college', 'product management', 'prof.', 'professional trainer', 'professor', 'professor of mathematics', 'proprietário(a)', 'quantitative aptitude faculty', 'radiology professional', 'research', 'sales', 'science teacher', 'senior lecturer', 'software /solution provider', 'subsidiary sales (ise)', 'surgery professional', 'system integrator', 'teacher', 'teacher/middle school coordinator', 'technical', 'the big boss', 'this is a consume display requirement for home purpose.', 'tierarzt', 'trainee', 'técnico', 'unpaid', 'vice president', 'vicepresident', 'vp']
# ['LGEAF', 'LGEAG', 'LGEAP', 'LGEAR', 'LGEAS', 'LGEBN', 'LGEBT', 'LGECB', 'LGECH', 'LGECI', 'LGECL', 'LGECZ', 'LGEDG', 'LGEEB', 'LGEEF', 'LGEEG', 'LGEES', 'LGEFS', 'LGEGF', 'LGEHK', 'LGEHS', 'LGEIL', 'LGEIN', 'LGEIR', 'LGEIS', 'LGEJP', 'LGEKR', 'LGELA', 'LGELF', 'LGEMC', 'LGEMK', 'LGEML', 'LGEMS', 'LGEPH', 'LGEPL', 'LGEPR', 'LGEPS', 'LGEPT', 'LGERA', 'LGERO', 'LGESA', 'LGESJ', 'LGESL', 'LGESP', 'LGESW', 'LGETH', 'LGETK', 'LGETT', 'LGEUK', 'LGEUR', 'LGEUS', 'LGEVH', 'LGEYK']
# ['(select id_timeline)', '09-02-2022 requested for boq of requirement', '14:00~15:00', '14th aug- aggressive price required as he has got price from outside delhi', '14th-feb-2022 shared details.awaiting update from customer.', '25-nov-2021  no mobile number, sent a mail to customer', '29thsep2021:-no such requirement as of now', '3 months', '3 months ~ 6 months', '3_months_~_6_months', '4/8 months', '45 days', '6 months ~ 9 months', '6_months_~_9_months', '9 months - 1 year', '9 months ~ 1 year', '9_months_~_1_year', 'aggressive price required', 'already close in july purchse with rd', 'already connect with partner', 'already in discussion with partner from bangalore (kohinoor) and with mr. indraneel from corporate office', 'already in touch with customer', 'already in touch with customer from last 10 days. dropping it because we are already in touch', 'already in touch with him since long. he has not finalized yet. lead forwarded to rd', 'already in touch with partner.', 'already in touch with there team', 'already our customer, have shared prices for new requirement', 'already purchase with rd', 'already shared quotation through si.', 'already touch with customer for kiosk requirement', 'already touch with customers', 'already working on idb will create opp post clarfying on signage', 'already working with end user on this requirement.', 'asked to call back later, i had shared this lead with rd to take it further.', 'asked to call back tomorrow morning, not responding', 'asked to call back tomorrow, i had shared this enquiry with rd.', 'asked to call later.', 'asked to call next week', 'asked to call on 4th may', 'asked to contact him after 8th jan.', 'asked to send details', 'asked to share details on mail. he will update if there is any requirement', 'assigned to partner. intial meeting done. will convert to opp post complete info', 'at present not required,', 'being followed up', 'being followed up.', 'bodeli, requirement pending new quote send close in this month end.', 'budget issue', 'budget issue.', 'budget low hence client have not went ahead.', 'budget problem', 'budget problem.', 'busy, call later', 'busy. need to call back', 'call after 3 june', 'call and discused no requirement.', 'call and discused to custome customer wants demo.', 'call back again on 30/04', 'call back later', 'call back later, in first week march', 'call back tomorrow 28/09', 'call not connecting', 'call not picking', 'called to know the price of idb', 'client have seen the demo. he needed for bigger room and the camera quality and speaker tracking were the main required feature. as of now, his budget is around 2 lacs and need bigger size solution. there is no response from client post demo hence closing', 'client is cross checking on prices. its a rc case of subway and the franchisee is trying to get pricing from elsewhere.', 'client is exploring. he will discuss once details sent. details mailed to him. as per recent discussion, he is not exploring as of now.', 'client is looking for 86" display with vc solution, they will go for demo next week and decide on procuring our tr3dj, details shared with client on mail.', 'client is not having any requirement, he was only browsing through the produt hence closig in system. although the details of idb are mailed to client.', 'client is not looking now and he was interested with only inbuilt ops option. hence closing in system as he is not responding to calls.', 'client is not responding calls, following up and keep the update tracked', 'client not anwering calls and asked there is no requirement. he was trying to check prices for one 65 touch requirement of existing client.', 'client not interested in product.. receing call and not answering properly', 'client shall get back for exploring demo of idb, post that they will decide on procuring the same.', 'client was busy, asked to call back later, interested in exploring our idb', 'client was driving and asked to call back later, will folloup and ke ...

# %%
# 위에서 전처리할때는 한번에 concat해서 진행하고 분리한다. 
for col in label_columns:  
    df_train[col] = df_all.iloc[: len(df_train)][col]
    df_test[col] = df_all.iloc[len(df_train) :][col]

# %%
x_train, x_val, y_train, y_val = train_test_split(
    df_train.drop("is_converted", axis=1),
    df_train["is_converted"],
    test_size=0.2,
    shuffle=True,
    random_state=400,)

# %%
model = DecisionTreeClassifier()
# 결측치를 0으로 처리
model.fit(x_train.fillna(0), y_train)
# Out:
# DecisionTreeClassifier()

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = confusion_matrix(y_test, y_pred, labels=[True, False])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
pred = model.predict(x_val.fillna(0))
get_clf_eval(y_val, pred)
# Out:
# 오차행렬:
#  [[  734   213]
#  [  248 10665]]
#
# 정확도: 0.9611
# 정밀도: 0.7475
# 재현율: 0.7751
# F1: 0.7610
