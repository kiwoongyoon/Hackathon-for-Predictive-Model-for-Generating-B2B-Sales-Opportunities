# %%
# !pip install category_encoders 
# !pip install optuna 
import pandas as pd
import numpy as np
import random 
import re 
import os 
import warnings
warnings.filterwarnings("ignore")
import category_encoders as ce 

from sklearn.metrics import (    accuracy_score,    confusion_matrix,f1_score,precision_score, recall_score,roc_auc_score)
from sklearn.metrics import make_scorer
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold,cross_val_score, StratifiedShuffleSplit

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE , ADASYN

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier,ExtraTreesClassifier,GradientBoostingClassifier,HistGradientBoostingClassifier,AdaBoostClassifier
from sklearn.ensemble import VotingClassifier,StackingClassifier
from sklearn.neighbors import KNeighborsClassifier
from catboost import CatBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

import optuna
from optuna.samplers import TPESampler

from sklearn.base import BaseEstimator, TransformerMixin, ClassifierMixin, clone
from sklearn.preprocessing import FunctionTransformer, StandardScaler, LabelEncoder

# %%
import random
import os
import pandas as pd
import numpy as np
import re
import warnings
warnings.filterwarnings('ignore')
from collections import Counter
import importlib
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import MaxNLocator
from datetime import datetime, timedelta


import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline
sns.set(style="whitegrid")  # 그래프 스타일 설정


import matplotlib
import matplotlib.font_manager
#[f.name for f in matplotlib.font_manager.fontManager.ttflist if 'Nanum' in f.name]
import platform

plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Windows':
    path = "c:/Windows/Fonts/NanumBarunGothic.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Linux':
    rc('font', family='NanumBarunGothic')
else:
    print('Unknown system... sorry~~~~~~')

# %%
pd.set_option('display.max_rows', 500)
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42)
nation_corp = {
    'Austria': ['LGEAG'],    'Czech Republic': ['LGECZ'],    'France': ['LGEFS'],    'Germany': ['LGEDG'],    'Greece': ['LGEHS'],    'Hungary': ['LGEMK'],    'Italy': ['LGEIS'],    'Netherlands': ['LGESC', 'LGEEH', 'LGEBN'],    'Poland': ['LGEWR', 'LGEPL', 'LGEMA'],    'Portugal': ['LGEPT','LGEBT'],
    'EUs': ['LGEEB'],    'Romania': ['LGERO'],    'Spain': ['LGEES'],    'Sweden': ['LGENO', 'LGESW'],    'United Kingdom': ['LGEUK'],      'Kazakhstan': ['LGEAK'],    'Russia': ['LGERM', 'LGERI', 'LGERA'],
    'Ukraine': ['LGEUR'],    'Latvia': ['LGELV','LGELA'],    'Algeria': ['LGEAS'],
    'Egypt': ['LGEEG'],    'Jordan': ['LGELF'],    'Kenya': ['LGESK','LGEEF'],    'Morocco': ['LGEMC'],
    'Saudi Arabia': ['LGESJ'],    'Iran':['LGEIR'],     'Israel':['LGEYK'],     'The Republic of South Africa': ['LGESA'],
    'Tunisia': ['LGETU'],    'U.A.E': ['LGEOT', 'LGEDF', 'LGEGF', 'LGEME', 'LGEAF'],    'Nigeria': ['LGEAO', 'LGENI'],
    'Turkey': ['LGETK', 'LGEAT'],    'Australia': ['LGEAP'],
    'China': ['LGEQA', 'LGETL', 'LGECH', 'LGEYT', 'LGETR', 'LGETA', 'LGESY', 'LGESH', 'LGEQH', 'LGEQD', 'LGEPN', 'LGEND', 'LGEKS', 'LGEHZ', 'LGEHN', 'LGEHK'],
    'India': ['LGEIL'],    'Indonesia': ['LGEIN'],    'Japan': ['LGEJP'],    'Malaysia': ['LGEML'],    'Philippines': ['LGEPH'],
    'Singapore': ['LGESL'],    'Taiwan': ['LGETT'],    'Korea' :['LGEKR'],    'Thailand': ['LGETH'],    'Vietnam': ['LGEVN','LGEVH'],
     'Canada': ['LGECI'],    'Mexico': ['LGERS', 'LGEMX', 'LGEMS', 'LGEMM'],    'United States': ['LGEMR', 'LGEUS', 'LGEMU', 'LGEAI'],
    'Argentina': ['LGEAG','LGEAR'],    'Brazil': ['LGEBR','LGESP'],    'Chile': ['LGECL'],    'Colombia': ['LGEVZ', 'LGECB'],
    'Panama': ['Guatemala', 'LGEPS'],    'Peru': ['LGEPR']}
continent_nation={
    'Europe':['EUs','Austria', 'Czech Republic' ,'France' ,'Germany', 'Greece' ,'Hungary', 'Italy', 'Netherlands' ,'Poland' ,'Portugal' ,'Romania', 'Spain' ,'Sweden','United Kingdom'], 
    'Russia and CIS':['Kazakhstan','Russia', 'Ukraine', 'Latvia'],     'Africa and MiddleEast': ['Israel','Iran','Algeria', 'Egypt', 'Jordan', 'Kenya', 'Morocco','Saudi Arabia','The Republic of South Africa','Tunisia', 'U.A.E', 'Nigeria', 'Turkey'], 
    'Asia':['Korea','Australia','China','India','Indonesia','Japan','Malaysia','Philippines','Singapore','Taiwan','Thailand','Vietnam'], 
    'NorthAmerica' : ['Canada','Mexico','United States'],    'SouthAmerica' :['Argentina','Brazil','Chile','Colombia','Panama','Peru']
    
}
hemisphere = {
    'Northern': ['EUs', 'Austria', 'Czech Republic', 'France', 'Germany', 'Greece', 'Hungary', 'Italy', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Spain', 'Sweden', 'United Kingdom', 'Kazakhstan', 'Russia', 'Ukraine', 'Latvia', 'Israel', 'Iran', 'Jordan', 'Morocco', 'Saudi Arabia', 'Tunisia', 'Turkey', 'Korea', 'China', 'Japan', 'Taiwan', 'Canada', 'United States', 'Mexico', 'Panama'],
    'Southern': ['Algeria', 'Egypt', 'Kenya', 'The Republic of South Africa', 'U.A.E', 'Nigeria', 'Australia', 'India', 'Indonesia', 'Malaysia', 'Philippines', 'Singapore', 'Thailand', 'Vietnam', 'Argentina', 'Brazil', 'Chile', 'Colombia', 'Peru']
}
mapping_dict = {
#     "Toi muon tim hieu thong tin ky thuat, gia ca cua sp de su dung": "Product Information",
#     "tôi cần tham khảo giá và giải pháp từ LG": "Quotation or Purchase Consultation",
#     "Vui lòng báo giá giúp mình sản phẩm đo thân nhiệt Xin cảm ơn": "Request for quotation or purchase",
#     "LED Signage": "Product Information",
#     "Standalone": "Product Information",
#     "for school": "Other",
#     "Not specified": "Other",
#     "Intégrateur historique du George V": "Other",
#     "Solicito apoyo para realizar cotizacion de los dispositivos que ofrecen en la solución One Quick:": "Quotation or Purchase Consultation",
#     "Pantallas Interactivas para Clinicas": "Product Information",
#     "Hotel TV products": "Product Information",
#     "VRF": "Product Information",
#     "Preciso de um monitor médico para radiografia convencional e tomogrtafia.": "Sales Inquiry",
    "others": "Other",
    "Others": "Other",
    "other_": "Other",
    "other": "Other",
    "Etc.": "ETC.",
#     "window facing product": "Product Information",
#     "Digital platform": "Product Information",
#     "(Select ID_Needs)": "Other",
#     "One Quick:Flex": "Product Information",
#     "AIO": "Product Information",
#     "Needs": "Other",
#     "Hospital TV": "Product Information",
#     "i want to know the details about it": "Product Information",
#     "EDUCATIONAL EQUIPMENTS": "Product Information",
#     "TV interactive": "Product Information",
#     "Hola me pueden cotizar 19 pantallas interactivas de 100 pulgadas entregadas en Guayaquil -Ecuador.": "Request for quotation or purchase",
#     "teach": "Other",
#     "Display Textbook and photos": "Usage or technical consultation",
#     "High inch 86 / 98 or 110": "Product Information",
#     "quotation_": "Request for quotation or purchase",
#     "display product": "Product Information",
#     "first Info and pricing": "Quotation or Purchase Consultation",
#     "estoy buscando para Ecuador este producto LG MAGNIT micro LED, para un cliente de 138 pulgadas, con envió marítimo.": "Sales Inquiry",
#     "Evento_SdelEstero": "Other",
#     "probeam precio": "Sales Inquiry",
#     "media inquiry": "Sales Inquiry",
#     "Video Wall": "Product Information",
}

# %%
# 데이터 생성 및 전처리 함수 
def get_datas():
    train = pd.read_csv("train.csv")
    test = pd.read_csv("submission.csv").drop(['id','is_converted'], axis =1) # 테스트 데이터(제출파일의 데이터)
    train['is_converted']=np.where(train['is_converted']==True,1,0)
    return train, test 


def delete_cols(data, cols):
    data = data.drop(columns=cols)
    return data

def log_transform(data,cols):
    for col in cols :
        data[col+'log']=np.log1p(data[col]) 
    return data 


def eda_expected_timeline(df):
    
    def timeline_label(time):
    
        time = str(time).lower().replace(' ','').replace('_','').replace('/','').replace(',','').replace('~','').replace('&','').replace('-','').replace('.','')
        
        if time == 'lessthan3months':
            result = 'less than 3 months'
        elif time == '3months6months':
            result = '3 months ~ 6 months'
        elif time == '6months9months':
            result = '6 months ~ 9 months'
        elif time == '9months1year':
            result = '9 months ~ 1 year'
        elif time == 'morethanayear':
            result = 'more than a year'
        else:
            result = 'aimers_0203'
            
        return result
    
    df['expected_timeline'] = df['expected_timeline'].apply(timeline_label)
    
    return df


# inquiry type 전처리하기 
def eda_inquiry_type(df):
    df['inquiry_type']= df['inquiry_type'].map(mapping_dict).fillna(train['inquiry_type'])
    df.loc[df['inquiry_type'].str.contains('Solicito apoyo para realizar', na=False), 'inquiry_type'] = 'Quotation or Purchase Consultation'
    df['inquiry_type'] = df['inquiry_type'].str.lower()
    replacement = {'/': ' ', '-':' ', '_':' '}
    df['inquiry_type'].replace(replacement, regex=True, inplace=True)
    return df


#customer type 처리 
def customer_type(data):
    data['customer_type']=data['customer_type'].fillna('none') 
    return data

# total_area 변수로 통일
def eda_business_area(df):
    for col in ['business_area','business_subarea']:
        df[col] = df[col].str.lower()
        df[col] = df[col].str.replace(" ", "") 
        df[col] = df[col].str.replace(r'[^\w\s]', "") 
        df[col] = df[col].fillna('nan') 
    df['total_area'] = df['business_area'].astype(str) + df['business_subarea'].astype(str)
    return df 

# 새로운 국가명, 대륙 열을 만들기 
def get_nation_continent(df):
    nation_corp_reverse ={v:k for k , values in nation_corp.items() for v in values }
    df['nation']=df['response_corporate'].map(nation_corp_reverse)
    continent_nation_reverse ={v:k for k , values in continent_nation.items() for v in values }
    df['continent']=df['nation'].map(continent_nation_reverse)
#     df = df.drop('customer_country',axis=1) 
    return df 

#라벨 인코딩 
def label_encoding(series: pd.Series) -> pd.Series:
    my_dict = {}
    series = series.astype(str)
    for idx, value in enumerate(sorted(series.unique())):
        my_dict[value] = idx
    series = series.map(my_dict)
    return series

# com_reg_ver_win_rate 최빈값으로 채우기 
def com_reg_fill(train,test):
    train['com_reg_ver_win_rate'] = train['com_reg_ver_win_rate'].fillna(train['com_reg_ver_win_rate'].mode()[0])
    test['com_reg_ver_win_rate'] = test['com_reg_ver_win_rate'].fillna(train['com_reg_ver_win_rate'].mode()[0])
    return train,test

def timeline_tonumber(row):
    if row['expected_timeline'] == 'less than 3 months':
        return int(1)
    elif row['expected_timeline'] == '3 months ~ 6 months':
        return int(3)
    elif row['expected_timeline'] == '6 months ~ 9 months':
        return int(6)
    elif row['expected_timeline'] == '9 months ~ 1 year':
        return int(9)    
    elif row['expected_timeline'] =='aimer_0203':
        return np.nan
    else : 
        return int(12)
    
def create_grouped_features(train, test, group, numeric_var):
    # 범주형 특성들에 대해서 다른 수치형 데이터의 중앙값, 최대, 합을 새로운 열로 추가하기 
    train = train.copy()
    test = test.copy()
    aggs = ['median', 'max','sum']
    for agg in aggs:
        # groupby 후 aggregation
        a1 = train.groupby([group])[numeric_var].agg(agg).to_dict()
        # 새로운 feature 생성
        train[numeric_var+'_'+group+'_'+agg] = train[group].map(a1)
        test[numeric_var+'_'+group+'_'+agg] = test[group].map(a1)
    return train, test

def do_scale(train,test, scale_cols) :
    for c in scale_cols:
        min_value = train[c].min()
        max_value = train[c].max()
        train[c] = (train[c] - min_value) / (max_value - min_value)
        test[c] = (test[c] - min_value) / (max_value - min_value)
    return train,test

# %%
groups = ['business_unit','customer_idx']
numeric_vars = ['historical_existing_cnt', 'lead_desc_length']
scale_cols = ['com_reg_ver_win_rate','historical_existing_cnt', 'lead_desc_length','ver_win_rate_x']

# %%
# data 갖고오기 
train,test= get_datas() 

# 스케일링 하기 
train,test =do_scale(train,test,scale_cols)
# 범주형 데이터에 대해 수치형 데이터 통계값 추가
for group in groups:
    for numeric_var in numeric_vars:
        train, test = create_grouped_features(train, test, group, numeric_var)
        
# 전처리, 로그변환 수행하기 
columns_to_log=['com_reg_ver_win_rate','lead_desc_length']
train,test= log_transform(train,columns_to_log ),log_transform(test,columns_to_log)
train,test =eda_business_area(train),eda_business_area(test)
train,test= get_nation_continent(train),get_nation_continent(test)
train,test=eda_expected_timeline(train) ,eda_expected_timeline(test)
train,test=customer_type(train) ,customer_type(test)
train,test=eda_inquiry_type(train) ,eda_inquiry_type(test)


for col in ['customer_idx','customer_type',]:
    train[col+'count'] =train[col].map(train[col].value_counts())
    test[col+'count'] =test[col].map(train[col].value_counts())
    

train['idx_unit'] = train['customer_idx'].astype(str)+train['business_unit'].astype(str)
test['idx_unit'] = test['customer_idx'].astype(str)+test['business_unit'].astype(str)
train['idx_posi'] = train['customer_idx'].astype(str)+train['customer_position'].astype(str)
test['idx_posi'] = test['customer_idx'].astype(str)+test['customer_position'].astype(str)
train['conti_inquiry'] = train['continent'].astype(str)+train['inquiry_type'].astype(str)
test['conti_inquiry'] = test['continent'].astype(str)+test['inquiry_type'].astype(str)
# train['job_unit'] = train['business_unit'].astype(str)+train['customer_job'].astype(str)
# test['job_unit'] = test['business_unit'].astype(str)+test['customer_job'].astype(str)
#0.717 나옴 4개 변수

# %%
# country.1지우지말기 
columns_to_delete=['customer_country']
# columns_to_delete=[]
train,test =delete_cols(train, columns_to_delete), delete_cols(test,columns_to_delete)

cols = [     'customer_country',    "business_subarea",    "business_area",    "business_unit",    "customer_type",    "enterprise",    "customer_job",    "inquiry_type",    "product_category",    "product_subcategory",    "product_modelname",    "customer_position",
      'customer_country.1', "response_corporate", "expected_timeline",
'nation','continent','lead_owner','idx_posi', 'conti_inquiry', 'idx_unit','bant_submit'
,'total_area'   ]
label_columns =list(set(cols)-set(columns_to_delete))

from category_encoders import CatBoostEncoder
enc = CatBoostEncoder(cols=label_columns)
enc.fit(train[label_columns], train['is_converted'])  # 'target'은 실제 데이터의 타겟 변수 이름에 맞게 변경
# 인코딩 적용
train[label_columns] = enc.transform(train[label_columns])
test[label_columns] = enc.transform(test[label_columns])

# %%
test = test.fillna(0)
train = train.fillna(0)
x = train.drop('is_converted', axis=1)
y = train.is_converted

# %% [markdown]
# # Model

# %%
#sota : random_state = 42

dtc = DecisionTreeClassifier(random_state=i) 
dtc.fit(x,y)

xgb = XGBClassifier(random_state=i)
xgb.fit(x,y)

lgb = LGBMClassifier(random_state=i)
lgb.fit(x,y)

cat = CatBoostClassifier(random_state=i)
cat.fit(x,y)


preds1 = dtc.predict_proba(test)[:,1]
preds2 = xgb.predict_proba(test)[:,1]
preds3 = lgb.predict_proba(test)[:,1]
preds4 = cat.predict_proba(test)[:,1]

preds1 = np.array(preds1).reshape(1,-1)
preds2 = np.array(preds2).reshape(1,-1)
preds3 = np.array(preds3).reshape(1,-1)
preds4 = np.array(preds4).reshape(1,-1)
preds2 = np.where(preds2 >= 0.008, 1, 0) #0.01
preds3 = np.where(preds3 >= 0.008, 1, 0)
preds4 = np.where(preds4 >= 0.008, 1, 0)


all_preds = np.concatenate((preds1,preds2),axis=0)
all_preds = np.concatenate((all_preds,preds3),axis=0)
all_preds = np.concatenate((all_preds,preds4),axis=0)

final_preds = np.sum(all_preds,axis=0)
final_prediction = np.where(final_preds >= 1, 1, 0) #1
np.sum(final_prediction)
# Out:
# [LightGBM] [Info] Number of positive: 4850, number of negative: 54449
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009028 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3892
# [LightGBM] [Info] Number of data points in the train set: 59299, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.081789 -> initscore=-2.418286
# [LightGBM] [Info] Start training from score -2.418286
# Learning rate set to 0.058888
# 0:	learn: 0.5633549	total: 12.9ms	remaining: 12.9s
# 1:	learn: 0.4798971	total: 24.4ms	remaining: 12.2s
# 2:	learn: 0.3963466	total: 37.2ms	remaining: 12.3s
# 3:	learn: 0.3422475	total: 49.2ms	remaining: 12.3s
# 4:	learn: 0.2930075	total: 60ms	remaining: 11.9s
# 5:	learn: 0.2415204	total: 69.4ms	remaining: 11.5s
# 6:	learn: 0.1926921	total: 80.7ms	remaining: 11.4s
# 7:	learn: 0.1619237	total: 90.7ms	remaining: 11.2s
# 8:	learn: 0.1482707	total: 101ms	remaining: 11.2s
# 9:	learn: 0.1278666	total: 112ms	remaining: 11.1s
# 10:	learn: 0.1123509	total: 123ms	remaining: 11.1s
# 11:	learn: 0.1040857	total: 133ms	remaining: 10.9s
# 12:	learn: 0.0936052	total: 144ms	remaining: 10.9s
# 13:	learn: 0.0889585	total: 153ms	remaining: 10.8s
# 14:	learn: 0.0828100	total: 163ms	remaining: 10.7s
# 15:	learn: 0.0777247	total: 174ms	remaining: 10.7s
# 16:	learn: 0.0738030	total: 184ms	remaining: 10.6s
# 17:	learn: 0.0708777	total: 193ms	remaining: 10.5s
# 18:	learn: 0.0679689	total: 205ms	remaining: 10.6s
# 19:	learn: 0.0649867	total: 218ms	remaining: 10.7s
# 20:	learn: 0.0625930	total: 230ms	remaining: 10.7s
# 21:	learn: 0.0600055	total: 241ms	remaining: 10.7s
# 22:	learn: 0.0584177	total: 253ms	remaining: 10.7s
# 23:	learn: 0.0571248	total: 264ms	remaining: 10.8s
# 24:	learn: 0.0565610	total: 275ms	remaining: 10.7s
# 25:	learn: 0.0559841	total: 284ms	remaining: 10.7s
# 26:	learn: 0.0550996	total: 296ms	remaining: 10.7s
# 27:	learn: 0.0543877	total: 306ms	remaining: 10.6s
# 28:	learn: 0.0535379	total: 316ms	remaining: 10.6s
# 29:	learn: 0.0526297	total: 327ms	remaining: 10.6s
# 30:	learn: 0.0519439	total: 338ms	remaining: 10.6s
# 31:	learn: 0.0511403	total: 350ms	remaining: 10.6s
# 32:	learn: 0.0507037	total: 361ms	remaining: 10.6s
# 33:	learn: 0.0498796	total: 372ms	remaining: 10.6s
# 34:	learn: 0.0492363	total: 382ms	remaining: 10.5s
# 35:	learn: 0.0489789	total: 391ms	remaining: 10.5s
# 36:	learn: 0.0485208	total: 403ms	remaining: 10.5s
# 37:	learn: 0.0480878	total: 416ms	remaining: 10.5s
# 38:	learn: 0.0477735	total: 428ms	remaining: 10.5s
# 39:	learn: 0.0476338	total: 438ms	remaining: 10.5s
# 40:	learn: 0.0474634	total: 447ms	remaining: 10.5s
# 41:	learn: 0.0471730	total: 457ms	remaining: 10.4s
# 42:	learn: 0.0468613	total: 467ms	remaining: 10.4s
# 43:	learn: 0.0464324	total: 479ms	remaining: 10.4s
# 44:	learn: 0.0461213	total: 490ms	remaining: 10.4s
# 45:	learn: 0.0459778	total: 501ms	remaining: 10.4s
# 46:	learn: 0.0458212	total: 510ms	remaining: 10.3s
# 47:	learn: 0.0456170	total: 520ms	remaining: 10.3s
# 48:	learn: 0.0454750	total: 528ms	remaining: 10.3s
# 49:	learn: 0.0453336	total: 537ms	remaining: 10.2s
# 50:	learn: 0.0451426	total: 545ms	remaining: 10.1s
# 51:	learn: 0.0449364	total: 553ms	remaining: 10.1s
# 52:	learn: 0.0447727	total: 561ms	remaining: 10s
# 53:	learn: 0.0446341	total: 570ms	remaining: 9.98s
# 54:	learn: 0.0443610	total: 579ms	remaining: 9.94s
# 55:	learn: 0.0442802	total: 587ms	remaining: 9.89s
# 56:	learn: 0.0441427	total: 595ms	remaining: 9.84s
# 57:	learn: 0.0440611	total: 603ms	remaining: 9.79s
# 58:	learn: 0.0438726	total: 611ms	remaining: 9.75s
# 59:	learn: 0.0437749	total: 621ms	remaining: 9.73s
# 60:	learn: 0.0437101	total: 629ms	remaining: 9.67s
# 61:	learn: 0.0435217	total: 638ms	remaining: 9.65s
# 62:	learn: 0.0433479	total: 647ms	remaining: 9.62s
# 63:	learn: 0.0431879	total: 656ms	remaining: 9.59s
# 64:	learn: 0.0430650	total: 666ms	remaining: 9.58s
# 65:	learn: 0.0429983	total: 674ms	remaining: 9.54s
# 66:	learn: 0.0429068	total: 683ms	remaining: 9.51s
# 67:	learn: 0.0428405	total: 690ms	remaining: 9.46s
# 68:	learn: 0.0427682	total: 699ms	remaining: 9.43s
# 69:	learn: 0.0426209	total: 708ms	remaining: 9.41s
# 70:	learn: 0.0423901	total: 717ms	remaining: 9.38s
# 71:	learn: 0.0422753	total: 725ms	remaining: 9.35s
# 72:	learn: 0.0422298	total: 733ms	remaining: 9.3s
# 73:	learn: 0.0420317	total: 742ms	remaining: 9.28s
# 74:	learn: 0.0419877	total: 749ms	remaining: 9.24s
# 75:	learn: 0.0419542	total: 757ms	remaining: 9.21s
# 76:	learn: 0.0418479	total: 766ms	remaining: 9.18s
# 77:	learn: 0.0417520	total: 773ms	remaining: 9.13s
# 78:	learn: 0.0416648	total: 781ms	remaining: 9.1s
# 79:	learn: 0.0415740	total: 789ms	remaining: 9.07s
# 80:	learn: 0.0414838	total: 798ms	remaining: 9.05s
# 81:	learn: 0.0414223	total: 806ms	remaining: 9.03s
# 82:	learn: 0.0413870	total: 814ms	remaining: 8.99s
# 83:	learn: 0.0413528	total: 823ms	remaining: 8.97s
# 84:	learn: 0.0412856	total: 831ms	remaining: 8.94s
# 85:	learn: 0.0411800	total: 838ms	remaining: 8.91s
# 86:	learn: 0.0411524	total: 846ms	remaining: 8.88s
# 87:	learn: 0.0410842	total: 854ms	remaining: 8.85s
# 88:	learn: 0.0410155	total: 861ms	remaining: 8.81s
# 89:	learn: 0.0409625	total: 869ms	remaining: 8.79s
# 90:	learn: 0.0409090	total: 877ms	remaining: 8.76s
# 91:	learn: 0.0408563	total: 885ms	remaining: 8.73s
# 92:	learn: 0.0408185	total: 893ms	remaining: 8.71s
# 93:	learn: 0.0407257	total: 901ms	remaining: 8.68s
# 94:	learn: 0.0406889	total: 908ms	remaining: 8.65s
# 95:	learn: 0.0405885	total: 917ms	remaining: 8.64s
# 96:	learn: 0.0404589	total: 926ms	remaining: 8.62s
# 97:	learn: 0.0404073	total: 934ms	remaining: 8.59s
# 98:	learn: 0.0403518	total: 941ms	remaining: 8.57s
# 99:	learn: 0.0403070	total: 949ms	remaining: 8.54s
# 100:	learn: 0.0402109	total: 957ms	remaining: 8.52s
# 101:	learn: 0.0401762	total: 965ms	remaining: 8.49s
# 102:	learn: 0.0401430	total: 972ms	remaining: 8.47s
# 103:	learn: 0.0400811	total: 980ms	remaining: 8.44s
# 104:	learn: 0.0400513	total: 987ms	remaining: 8.41s
# 105:	learn: 0.0399585	total: 994ms	remaining: 8.38s
# 106:	learn: 0.0398366	total: 1s	remaining: 8.37s
# 107:	learn: 0.0397531	total: 1.01s	remaining: 8.36s
# 108:	learn: 0.0396948	total: 1.02s	remaining: 8.34s
# 109:	learn: 0.0396019	total: 1.03s	remaining: 8.35s
# 110:	learn: 0.0395710	total: 1.04s	remaining: 8.32s
# 111:	learn: 0.0395205	total: 1.05s	remaining: 8.3s
# 112:	learn: 0.0394435	total: 1.05s	remaining: 8.29s
# 113:	learn: 0.0394200	total: 1.06s	remaining: 8.26s
# 114:	learn: 0.0393908	total: 1.07s	remaining: 8.24s
# 115:	learn: 0.0393009	total: 1.08s	remaining: 8.22s
# 116:	learn: 0.0392005	total: 1.09s	remaining: 8.21s
# 117:	learn: 0.0391597	total: 1.09s	remaining: 8.19s
# 118:	learn: 0.0390750	total: 1.1s	remaining: 8.17s
# 119:	learn: 0.0389850	total: 1.11s	remaining: 8.15s
# 120:	learn: 0.0389058	total: 1.12s	remaining: 8.13s
# 121:	learn: 0.0388620	total: 1.13s	remaining: 8.12s
# 122:	learn: 0.0388091	total: 1.14s	remaining: 8.11s
# 123:	learn: 0.0387224	total: 1.15s	remaining: 8.09s
# 124:	learn: 0.0386321	total: 1.15s	remaining: 8.08s
# 125:	learn: 0.0385920	total: 1.16s	remaining: 8.06s
# 126:	learn: 0.0385396	total: 1.17s	remaining: 8.04s
# 127:	learn: 0.0385003	total: 1.18s	remaining: 8.03s
# 128:	learn: 0.0384619	total: 1.19s	remaining: 8.01s
# 129:	learn: 0.0383871	total: 1.19s	remaining: 7.99s
# 130:	learn: 0.0383054	total: 1.2s	remaining: 7.98s
# 131:	learn: 0.0382696	total: 1.21s	remaining: 7.96s
# 132:	learn: 0.0382093	total: 1.22s	remaining: 7.95s
# 133:	learn: 0.0381811	total: 1.23s	remaining: 7.93s
# 134:	learn: 0.0381528	total: 1.24s	remaining: 7.92s
# 135:	learn: 0.0381223	total: 1.24s	remaining: 7.89s
# 136:	learn: 0.0380947	total: 1.25s	remaining: 7.88s
# 137:	learn: 0.0380472	total: 1.26s	remaining: 7.86s
# 138:	learn: 0.0380087	total: 1.27s	remaining: 7.85s
# 139:	learn: 0.0379671	total: 1.27s	remaining: 7.84s
# 140:	learn: 0.0379328	total: 1.28s	remaining: 7.82s
# 141:	learn: 0.0378748	total: 1.29s	remaining: 7.81s
# 142:	learn: 0.0378259	total: 1.3s	remaining: 7.79s
# 143:	learn: 0.0377757	total: 1.31s	remaining: 7.78s
# 144:	learn: 0.0377403	total: 1.32s	remaining: 7.76s
# 145:	learn: 0.0377131	total: 1.32s	remaining: 7.75s
# 146:	learn: 0.0376416	total: 1.33s	remaining: 7.74s
# 147:	learn: 0.0375925	total: 1.34s	remaining: 7.72s
# 148:	learn: 0.0375397	total: 1.35s	remaining: 7.71s
# 149:	learn: 0.0374929	total: 1.36s	remaining: 7.69s
# 150:	learn: 0.0374661	total: 1.36s	remaining: 7.68s
# 151:	learn: 0.0374260	total: 1.37s	remaining: 7.66s
# 152:	learn: 0.0373848	total: 1.38s	remaining: 7.64s
# 153:	learn: 0.0373528	total: 1.39s	remaining: 7.63s
# 154:	learn: 0.0372669	total: 1.4s	remaining: 7.61s
# 155:	learn: 0.0372255	total: 1.4s	remaining: 7.6s
# 156:	learn: 0.0372007	total: 1.41s	remaining: 7.58s
# 157:	learn: 0.0371042	total: 1.42s	remaining: 7.57s
# 158:	learn: 0.0370667	total: 1.43s	remaining: 7.56s
# 159:	learn: 0.0370281	total: 1.44s	remaining: 7.55s
# 160:	learn: 0.0369768	total: 1.45s	remaining: 7.53s
# 161:	learn: 0.0369217	total: 1.45s	remaining: 7.52s
# 162:	learn: 0.0368862	total: 1.46s	remaining: 7.51s
# 163:	learn: 0.0368501	total: 1.47s	remaining: 7.49s
# 164:	learn: 0.0368119	total: 1.48s	remaining: 7.48s
# 165:	learn: 0.0367764	total: 1.49s	remaining: 7.46s
# 166:	learn: 0.0367310	total: 1.49s	remaining: 7.45s
# 167:	learn: 0.0366621	total: 1.5s	remaining: 7.44s
# 168:	learn: 0.0366222	total: 1.51s	remaining: 7.42s
# 169:	learn: 0.0365628	total: 1.52s	remaining: 7.41s
# 170:	learn: 0.0365068	total: 1.53s	remaining: 7.4s
# 171:	learn: 0.0364857	total: 1.53s	remaining: 7.39s
# 172:	learn: 0.0364576	total: 1.54s	remaining: 7.38s
# 173:	learn: 0.0364332	total: 1.55s	remaining: 7.36s
# 174:	learn: 0.0363777	total: 1.56s	remaining: 7.35s
# 175:	learn: 0.0363534	total: 1.57s	remaining: 7.34s
# 176:	learn: 0.0362807	total: 1.58s	remaining: 7.33s
# 177:	learn: 0.0362182	total: 1.58s	remaining: 7.32s
# 178:	learn: 0.0361505	total: 1.59s	remaining: 7.31s
# 179:	learn: 0.0360405	total: 1.6s	remaining: 7.3s
# 180:	learn: 0.0360056	total: 1.61s	remaining: 7.29s
# 181:	learn: 0.0359831	total: 1.62s	remaining: 7.28s
# 182:	learn: 0.0359333	total: 1.63s	remaining: 7.26s
# 183:	learn: 0.0359031	total: 1.63s	remaining: 7.24s
# 184:	learn: 0.0358483	total: 1.64s	remaining: 7.24s
# 185:	learn: 0.0357883	total: 1.65s	remaining: 7.23s
# 186:	learn: 0.0357651	total: 1.66s	remaining: 7.22s
# 187:	learn: 0.0357303	total: 1.67s	remaining: 7.21s
# 188:	learn: 0.0357175	total: 1.68s	remaining: 7.19s
# 189:	learn: 0.0356793	total: 1.68s	remaining: 7.18s
# 190:	learn: 0.0356465	total: 1.69s	remaining: 7.17s
# 191:	learn: 0.0356107	total: 1.7s	remaining: 7.16s
# 192:	learn: 0.0355758	total: 1.71s	remaining: 7.15s
# 193:	learn: 0.0355183	total: 1.72s	remaining: 7.14s
# 194:	learn: 0.0354924	total: 1.73s	remaining: 7.13s
# 195:	learn: 0.0354204	total: 1.74s	remaining: 7.12s
# 196:	learn: 0.0353619	total: 1.74s	remaining: 7.11s
# 197:	learn: 0.0353403	total: 1.75s	remaining: 7.09s
# 198:	learn: 0.0353202	total: 1.76s	remaining: 7.08s
# 199:	learn: 0.0352675	total: 1.77s	remaining: 7.07s
# 200:	learn: 0.0352249	total: 1.77s	remaining: 7.05s
# 201:	learn: 0.0351768	total: 1.78s	remaining: 7.04s
# 202:	learn: 0.0351331	total: 1.79s	remaining: 7.03s
# 203:	learn: 0.0350729	total: 1.8s	remaining: 7.02s
# 204:	learn: 0.0350073	total: 1.81s	remaining: 7s
# 205:	learn: 0.0349856	total: 1.81s	remaining: 6.99s
# 206:	learn: 0.0349564	total: 1.82s	remaining: 6.98s
# 207:	learn: 0.0349217	total: 1.83s	remaining: 6.96s
# 208:	learn: 0.0348717	total: 1.84s	remaining: 6.95s
# 209:	learn: 0.0347999	total: 1.85s	remaining: 6.95s
# 210:	learn: 0.0347728	total: 1.85s	remaining: 6.93s
# 211:	learn: 0.0347312	total: 1.86s	remaining: 6.92s
# 212:	learn: 0.0347026	total: 1.87s	remaining: 6.91s
# 213:	learn: 0.0346604	total: 1.88s	remaining: 6.9s
# 214:	learn: 0.0346344	total: 1.89s	remaining: 6.88s
# 215:	learn: 0.0345941	total: 1.89s	remaining: 6.87s
# 216:	learn: 0.0345555	total: 1.9s	remaining: 6.86s
# 217:	learn: 0.0344909	total: 1.91s	remaining: 6.85s
# 218:	learn: 0.0344830	total: 1.92s	remaining: 6.84s
# 219:	learn: 0.0344534	total: 1.92s	remaining: 6.82s
# 220:	learn: 0.0344136	total: 1.93s	remaining: 6.81s
# 221:	learn: 0.0343439	total: 1.94s	remaining: 6.8s
# 222:	learn: 0.0343094	total: 1.95s	remaining: 6.79s
# 223:	learn: 0.0342702	total: 1.96s	remaining: 6.78s
# 224:	learn: 0.0342062	total: 1.97s	remaining: 6.77s
# 225:	learn: 0.0341672	total: 1.97s	remaining: 6.76s
# 226:	learn: 0.0341451	total: 1.98s	remaining: 6.74s
# 227:	learn: 0.0341323	total: 1.99s	remaining: 6.73s
# 228:	learn: 0.0340972	total: 2s	remaining: 6.72s
# 229:	learn: 0.0340730	total: 2s	remaining: 6.71s
# 230:	learn: 0.0340519	total: 2.01s	remaining: 6.69s
# 231:	learn: 0.0340282	total: 2.02s	remaining: 6.68s
# 232:	learn: 0.0340193	total: 2.02s	remaining: 6.67s
# 233:	learn: 0.0340072	total: 2.03s	remaining: 6.66s
# 234:	learn: 0.0339698	total: 2.04s	remaining: 6.65s
# 235:	learn: 0.0339435	total: 2.05s	remaining: 6.64s
# 236:	learn: 0.0339189	total: 2.06s	remaining: 6.63s
# 237:	learn: 0.0338986	total: 2.07s	remaining: 6.62s
# 238:	learn: 0.0338832	total: 2.07s	remaining: 6.6s
# 239:	learn: 0.0338785	total: 2.08s	remaining: 6.59s
# 240:	learn: 0.0338504	total: 2.09s	remaining: 6.58s
# 241:	learn: 0.0338012	total: 2.1s	remaining: 6.57s
# 242:	learn: 0.0337538	total: 2.1s	remaining: 6.56s
# 243:	learn: 0.0337168	total: 2.11s	remaining: 6.55s
# 244:	learn: 0.0336953	total: 2.12s	remaining: 6.54s
# 245:	learn: 0.0336696	total: 2.13s	remaining: 6.52s
# 246:	learn: 0.0336606	total: 2.14s	remaining: 6.51s
# 247:	learn: 0.0336272	total: 2.14s	remaining: 6.5s
# 248:	learn: 0.0336101	total: 2.15s	remaining: 6.49s
# 249:	learn: 0.0335627	total: 2.16s	remaining: 6.48s
# 250:	learn: 0.0335344	total: 2.17s	remaining: 6.47s
# 251:	learn: 0.0334448	total: 2.18s	remaining: 6.46s
# 252:	learn: 0.0334116	total: 2.19s	remaining: 6.45s
# 253:	learn: 0.0333687	total: 2.19s	remaining: 6.44s
# 254:	learn: 0.0333401	total: 2.2s	remaining: 6.43s
# 255:	learn: 0.0333217	total: 2.21s	remaining: 6.42s
# 256:	learn: 0.0333136	total: 2.22s	remaining: 6.41s
# 257:	learn: 0.0332804	total: 2.22s	remaining: 6.4s
# 258:	learn: 0.0332722	total: 2.23s	remaining: 6.38s
# 259:	learn: 0.0332130	total: 2.24s	remaining: 6.37s
# 260:	learn: 0.0332051	total: 2.25s	remaining: 6.36s
# 261:	learn: 0.0331761	total: 2.25s	remaining: 6.35s
# 262:	learn: 0.0331511	total: 2.26s	remaining: 6.34s
# 263:	learn: 0.0331205	total: 2.27s	remaining: 6.33s
# 264:	learn: 0.0330930	total: 2.28s	remaining: 6.32s
# 265:	learn: 0.0330854	total: 2.29s	remaining: 6.31s
# 266:	learn: 0.0330524	total: 2.29s	remaining: 6.3s
# 267:	learn: 0.0330135	total: 2.3s	remaining: 6.29s
# 268:	learn: 0.0329972	total: 2.31s	remaining: 6.28s
# 269:	learn: 0.0329899	total: 2.32s	remaining: 6.27s
# 270:	learn: 0.0329076	total: 2.33s	remaining: 6.26s
# 271:	learn: 0.0328634	total: 2.34s	remaining: 6.25s
# 272:	learn: 0.0328493	total: 2.34s	remaining: 6.24s
# 273:	learn: 0.0328376	total: 2.35s	remaining: 6.23s
# 274:	learn: 0.0327895	total: 2.36s	remaining: 6.22s
# 275:	learn: 0.0327828	total: 2.37s	remaining: 6.21s
# 276:	learn: 0.0327370	total: 2.38s	remaining: 6.2s
# 277:	learn: 0.0327037	total: 2.38s	remaining: 6.19s
# 278:	learn: 0.0326964	total: 2.39s	remaining: 6.18s
# 279:	learn: 0.0326716	total: 2.4s	remaining: 6.17s
# 280:	learn: 0.0326338	total: 2.41s	remaining: 6.16s
# 281:	learn: 0.0326087	total: 2.42s	remaining: 6.15s
# 282:	learn: 0.0325889	total: 2.42s	remaining: 6.14s
# 283:	learn: 0.0325458	total: 2.43s	remaining: 6.13s
# 284:	learn: 0.0325138	total: 2.44s	remaining: 6.12s
# 285:	learn: 0.0325047	total: 2.45s	remaining: 6.11s
# 286:	learn: 0.0324725	total: 2.46s	remaining: 6.1s
# 287:	learn: 0.0324618	total: 2.46s	remaining: 6.09s
# 288:	learn: 0.0324448	total: 2.47s	remaining: 6.08s
# 289:	learn: 0.0323947	total: 2.48s	remaining: 6.07s
# 290:	learn: 0.0323666	total: 2.49s	remaining: 6.06s
# 291:	learn: 0.0323397	total: 2.5s	remaining: 6.05s
# 292:	learn: 0.0323101	total: 2.5s	remaining: 6.04s
# 293:	learn: 0.0322807	total: 2.51s	remaining: 6.04s
# 294:	learn: 0.0322613	total: 2.52s	remaining: 6.03s
# 295:	learn: 0.0322117	total: 2.53s	remaining: 6.02s
# 296:	learn: 0.0322045	total: 2.54s	remaining: 6.01s
# 297:	learn: 0.0321621	total: 2.55s	remaining: 6s
# 298:	learn: 0.0321227	total: 2.55s	remaining: 5.99s
# 299:	learn: 0.0320908	total: 2.56s	remaining: 5.98s
# 300:	learn: 0.0320212	total: 2.57s	remaining: 5.97s
# 301:	learn: 0.0319761	total: 2.58s	remaining: 5.96s
# 302:	learn: 0.0319704	total: 2.59s	remaining: 5.95s
# 303:	learn: 0.0319424	total: 2.6s	remaining: 5.94s
# 304:	learn: 0.0319208	total: 2.6s	remaining: 5.93s
# 305:	learn: 0.0318697	total: 2.61s	remaining: 5.92s
# 306:	learn: 0.0318473	total: 2.62s	remaining: 5.91s
# 307:	learn: 0.0318130	total: 2.63s	remaining: 5.9s
# 308:	learn: 0.0317893	total: 2.63s	remaining: 5.89s
# 309:	learn: 0.0317849	total: 2.64s	remaining: 5.88s
# 310:	learn: 0.0317794	total: 2.65s	remaining: 5.87s
# 311:	learn: 0.0317405	total: 2.66s	remaining: 5.87s
# 312:	learn: 0.0316957	total: 2.67s	remaining: 5.86s
# 313:	learn: 0.0316444	total: 2.68s	remaining: 5.85s
# 314:	learn: 0.0316246	total: 2.68s	remaining: 5.84s
# 315:	learn: 0.0315882	total: 2.69s	remaining: 5.83s
# 316:	learn: 0.0315484	total: 2.7s	remaining: 5.82s
# 317:	learn: 0.0315223	total: 2.71s	remaining: 5.81s
# 318:	learn: 0.0314962	total: 2.71s	remaining: 5.8s
# 319:	learn: 0.0314484	total: 2.72s	remaining: 5.79s
# 320:	learn: 0.0314150	total: 2.73s	remaining: 5.78s
# 321:	learn: 0.0313817	total: 2.74s	remaining: 5.77s
# 322:	learn: 0.0313776	total: 2.75s	remaining: 5.76s
# 323:	learn: 0.0313662	total: 2.75s	remaining: 5.75s
# 324:	learn: 0.0313294	total: 2.76s	remaining: 5.74s
# 325:	learn: 0.0313229	total: 2.77s	remaining: 5.73s
# 326:	learn: 0.0312847	total: 2.78s	remaining: 5.72s
# 327:	learn: 0.0312669	total: 2.79s	remaining: 5.71s
# 328:	learn: 0.0312274	total: 2.79s	remaining: 5.7s
# 329:	learn: 0.0312090	total: 2.8s	remaining: 5.69s
# 330:	learn: 0.0311639	total: 2.81s	remaining: 5.68s
# 331:	learn: 0.0311492	total: 2.82s	remaining: 5.67s
# 332:	learn: 0.0311087	total: 2.83s	remaining: 5.66s
# 333:	learn: 0.0310749	total: 2.84s	remaining: 5.66s
# 334:	learn: 0.0310521	total: 2.85s	remaining: 5.65s
# 335:	learn: 0.0310188	total: 2.85s	remaining: 5.64s
# 336:	learn: 0.0310038	total: 2.86s	remaining: 5.63s
# 337:	learn: 0.0309767	total: 2.87s	remaining: 5.62s
# 338:	learn: 0.0309721	total: 2.88s	remaining: 5.61s
# 339:	learn: 0.0309376	total: 2.89s	remaining: 5.6s
# 340:	learn: 0.0309277	total: 2.89s	remaining: 5.59s
# 341:	learn: 0.0308458	total: 2.9s	remaining: 5.58s
# 342:	learn: 0.0307977	total: 2.91s	remaining: 5.58s
# 343:	learn: 0.0307872	total: 2.92s	remaining: 5.57s
# 344:	learn: 0.0307671	total: 2.93s	remaining: 5.56s
# 345:	learn: 0.0307249	total: 2.94s	remaining: 5.55s
# 346:	learn: 0.0307080	total: 2.94s	remaining: 5.54s
# 347:	learn: 0.0306916	total: 2.95s	remaining: 5.53s
# 348:	learn: 0.0306692	total: 2.96s	remaining: 5.52s
# 349:	learn: 0.0306413	total: 2.96s	remaining: 5.51s
# 350:	learn: 0.0306364	total: 2.97s	remaining: 5.5s
# 351:	learn: 0.0305922	total: 2.98s	remaining: 5.49s
# 352:	learn: 0.0305872	total: 2.99s	remaining: 5.48s
# 353:	learn: 0.0305272	total: 3s	remaining: 5.47s
# 354:	learn: 0.0305041	total: 3.01s	remaining: 5.46s
# 355:	learn: 0.0304868	total: 3.02s	remaining: 5.45s
# 356:	learn: 0.0304677	total: 3.02s	remaining: 5.45s
# 357:	learn: 0.0304374	total: 3.03s	remaining: 5.43s
# 358:	learn: 0.0304167	total: 3.04s	remaining: 5.42s
# 359:	learn: 0.0303914	total: 3.05s	remaining: 5.42s
# 360:	learn: 0.0303858	total: 3.05s	remaining: 5.41s
# 361:	learn: 0.0303393	total: 3.06s	remaining: 5.4s
# 362:	learn: 0.0303311	total: 3.07s	remaining: 5.39s
# 363:	learn: 0.0303269	total: 3.08s	remaining: 5.38s
# 364:	learn: 0.0303058	total: 3.09s	remaining: 5.37s
# 365:	learn: 0.0302639	total: 3.1s	remaining: 5.36s
# 366:	learn: 0.0302356	total: 3.1s	remaining: 5.35s
# 367:	learn: 0.0302092	total: 3.11s	remaining: 5.34s
# 368:	learn: 0.0301860	total: 3.12s	remaining: 5.33s
# 369:	learn: 0.0301488	total: 3.13s	remaining: 5.33s
# 370:	learn: 0.0301309	total: 3.13s	remaining: 5.31s
# 371:	learn: 0.0301047	total: 3.14s	remaining: 5.31s
# 372:	learn: 0.0300692	total: 3.15s	remaining: 5.3s
# 373:	learn: 0.0300441	total: 3.16s	remaining: 5.29s
# 374:	learn: 0.0299794	total: 3.17s	remaining: 5.28s
# 375:	learn: 0.0299492	total: 3.18s	remaining: 5.27s
# 376:	learn: 0.0299109	total: 3.19s	remaining: 5.26s
# 377:	learn: 0.0298769	total: 3.19s	remaining: 5.25s
# 378:	learn: 0.0298444	total: 3.2s	remaining: 5.25s
# 379:	learn: 0.0298303	total: 3.21s	remaining: 5.24s
# 380:	learn: 0.0298033	total: 3.22s	remaining: 5.23s
# 381:	learn: 0.0297779	total: 3.23s	remaining: 5.22s
# 382:	learn: 0.0297149	total: 3.23s	remaining: 5.21s
# 383:	learn: 0.0296881	total: 3.24s	remaining: 5.2s
# 384:	learn: 0.0296754	total: 3.25s	remaining: 5.2s
# 385:	learn: 0.0296660	total: 3.26s	remaining: 5.18s
# 386:	learn: 0.0296333	total: 3.27s	remaining: 5.18s
# 387:	learn: 0.0296081	total: 3.28s	remaining: 5.17s
# 388:	learn: 0.0295914	total: 3.29s	remaining: 5.16s
# 389:	learn: 0.0295735	total: 3.29s	remaining: 5.15s
# 390:	learn: 0.0295663	total: 3.3s	remaining: 5.14s
# 391:	learn: 0.0295422	total: 3.31s	remaining: 5.13s
# 392:	learn: 0.0295219	total: 3.32s	remaining: 5.12s
# 393:	learn: 0.0294840	total: 3.33s	remaining: 5.12s
# 394:	learn: 0.0294396	total: 3.33s	remaining: 5.11s
# 395:	learn: 0.0294268	total: 3.34s	remaining: 5.1s
# 396:	learn: 0.0293641	total: 3.35s	remaining: 5.09s
# 397:	learn: 0.0293501	total: 3.36s	remaining: 5.08s
# 398:	learn: 0.0293060	total: 3.37s	remaining: 5.07s
# 399:	learn: 0.0292887	total: 3.37s	remaining: 5.06s
# 400:	learn: 0.0292668	total: 3.38s	remaining: 5.05s
# 401:	learn: 0.0292387	total: 3.39s	remaining: 5.04s
# 402:	learn: 0.0292176	total: 3.4s	remaining: 5.03s
# 403:	learn: 0.0291910	total: 3.41s	remaining: 5.03s
# 404:	learn: 0.0291716	total: 3.41s	remaining: 5.01s
# 405:	learn: 0.0291339	total: 3.42s	remaining: 5.01s
# 406:	learn: 0.0291141	total: 3.43s	remaining: 5s
# 407:	learn: 0.0290880	total: 3.44s	remaining: 4.99s
# 408:	learn: 0.0290580	total: 3.45s	remaining: 4.98s
# 409:	learn: 0.0290011	total: 3.46s	remaining: 4.97s
# 410:	learn: 0.0289950	total: 3.46s	remaining: 4.96s
# 411:	learn: 0.0289823	total: 3.47s	remaining: 4.95s
# 412:	learn: 0.0289531	total: 3.48s	remaining: 4.95s
# 413:	learn: 0.0289187	total: 3.49s	remaining: 4.94s
# 414:	learn: 0.0288724	total: 3.5s	remaining: 4.93s
# 415:	learn: 0.0288598	total: 3.5s	remaining: 4.92s
# 416:	learn: 0.0288377	total: 3.51s	remaining: 4.91s
# 417:	learn: 0.0288128	total: 3.52s	remaining: 4.9s
# 418:	learn: 0.0287919	total: 3.53s	remaining: 4.89s
# 419:	learn: 0.0287751	total: 3.54s	remaining: 4.88s
# 420:	learn: 0.0287620	total: 3.54s	remaining: 4.87s
# 421:	learn: 0.0287406	total: 3.55s	remaining: 4.87s
# 422:	learn: 0.0287366	total: 3.56s	remaining: 4.86s
# 423:	learn: 0.0287002	total: 3.57s	remaining: 4.85s
# 424:	learn: 0.0286807	total: 3.58s	remaining: 4.84s
# 425:	learn: 0.0286654	total: 3.58s	remaining: 4.83s
# 426:	learn: 0.0286107	total: 3.59s	remaining: 4.82s
# 427:	learn: 0.0285719	total: 3.6s	remaining: 4.81s
# 428:	learn: 0.0285449	total: 3.61s	remaining: 4.8s
# 429:	learn: 0.0285260	total: 3.62s	remaining: 4.8s
# 430:	learn: 0.0285038	total: 3.63s	remaining: 4.79s
# 431:	learn: 0.0284816	total: 3.63s	remaining: 4.78s
# 432:	learn: 0.0284660	total: 3.64s	remaining: 4.77s
# 433:	learn: 0.0284297	total: 3.65s	remaining: 4.76s
# 434:	learn: 0.0284027	total: 3.66s	remaining: 4.75s
# 435:	learn: 0.0283772	total: 3.67s	remaining: 4.74s
# 436:	learn: 0.0283717	total: 3.67s	remaining: 4.73s
# 437:	learn: 0.0283498	total: 3.68s	remaining: 4.72s
# 438:	learn: 0.0283355	total: 3.69s	remaining: 4.71s
# 439:	learn: 0.0283133	total: 3.7s	remaining: 4.71s
# 440:	learn: 0.0282975	total: 3.71s	remaining: 4.7s
# 441:	learn: 0.0282650	total: 3.71s	remaining: 4.69s
# 442:	learn: 0.0282582	total: 3.72s	remaining: 4.68s
# 443:	learn: 0.0282104	total: 3.73s	remaining: 4.67s
# 444:	learn: 0.0281888	total: 3.74s	remaining: 4.66s
# 445:	learn: 0.0281632	total: 3.75s	remaining: 4.65s
# 446:	learn: 0.0281464	total: 3.75s	remaining: 4.64s
# 447:	learn: 0.0281263	total: 3.76s	remaining: 4.63s
# 448:	learn: 0.0281080	total: 3.77s	remaining: 4.63s
# 449:	learn: 0.0281045	total: 3.78s	remaining: 4.62s
# 450:	learn: 0.0280671	total: 3.79s	remaining: 4.61s
# 451:	learn: 0.0280440	total: 3.8s	remaining: 4.6s
# 452:	learn: 0.0280185	total: 3.81s	remaining: 4.59s
# 453:	learn: 0.0279975	total: 3.81s	remaining: 4.59s
# 454:	learn: 0.0279799	total: 3.82s	remaining: 4.58s
# 455:	learn: 0.0279661	total: 3.83s	remaining: 4.57s
# 456:	learn: 0.0279357	total: 3.84s	remaining: 4.56s
# 457:	learn: 0.0279139	total: 3.84s	remaining: 4.55s
# 458:	learn: 0.0278888	total: 3.85s	remaining: 4.54s
# 459:	learn: 0.0278554	total: 3.86s	remaining: 4.53s
# 460:	learn: 0.0278354	total: 3.87s	remaining: 4.52s
# 461:	learn: 0.0278264	total: 3.88s	remaining: 4.51s
# 462:	learn: 0.0277971	total: 3.88s	remaining: 4.51s
# 463:	learn: 0.0277854	total: 3.89s	remaining: 4.5s
# 464:	learn: 0.0277402	total: 3.9s	remaining: 4.49s
# 465:	learn: 0.0277176	total: 3.91s	remaining: 4.48s
# 466:	learn: 0.0276947	total: 3.92s	remaining: 4.47s
# 467:	learn: 0.0276770	total: 3.92s	remaining: 4.46s
# 468:	learn: 0.0276473	total: 3.94s	remaining: 4.46s
# 469:	learn: 0.0276334	total: 3.94s	remaining: 4.45s
# 470:	learn: 0.0275951	total: 3.95s	remaining: 4.44s
# 471:	learn: 0.0275709	total: 3.96s	remaining: 4.43s
# 472:	learn: 0.0275521	total: 3.96s	remaining: 4.42s
# 473:	learn: 0.0275314	total: 3.97s	remaining: 4.41s
# 474:	learn: 0.0275034	total: 3.98s	remaining: 4.4s
# 475:	learn: 0.0274734	total: 3.99s	remaining: 4.39s
# 476:	learn: 0.0274331	total: 4s	remaining: 4.38s
# 477:	learn: 0.0274151	total: 4.01s	remaining: 4.38s
# 478:	learn: 0.0273920	total: 4.01s	remaining: 4.37s
# 479:	learn: 0.0273589	total: 4.02s	remaining: 4.36s
# 480:	learn: 0.0273417	total: 4.03s	remaining: 4.35s
# 481:	learn: 0.0273218	total: 4.04s	remaining: 4.34s
# 482:	learn: 0.0273136	total: 4.04s	remaining: 4.33s
# 483:	learn: 0.0272930	total: 4.05s	remaining: 4.32s
# 484:	learn: 0.0272735	total: 4.06s	remaining: 4.31s
# 485:	learn: 0.0272616	total: 4.07s	remaining: 4.3s
# 486:	learn: 0.0272533	total: 4.08s	remaining: 4.29s
# 487:	learn: 0.0272113	total: 4.09s	remaining: 4.29s
# 488:	learn: 0.0271918	total: 4.09s	remaining: 4.28s
# 489:	learn: 0.0271763	total: 4.1s	remaining: 4.27s
# 490:	learn: 0.0271627	total: 4.11s	remaining: 4.26s
# 491:	learn: 0.0271259	total: 4.12s	remaining: 4.25s
# 492:	learn: 0.0270999	total: 4.13s	remaining: 4.24s
# 493:	learn: 0.0270898	total: 4.13s	remaining: 4.23s
# 494:	learn: 0.0270538	total: 4.14s	remaining: 4.22s
# 495:	learn: 0.0270388	total: 4.15s	remaining: 4.22s
# 496:	learn: 0.0270289	total: 4.16s	remaining: 4.21s
# 497:	learn: 0.0270186	total: 4.17s	remaining: 4.2s
# 498:	learn: 0.0269992	total: 4.17s	remaining: 4.19s
# 499:	learn: 0.0269666	total: 4.18s	remaining: 4.18s
# 500:	learn: 0.0269466	total: 4.19s	remaining: 4.17s
# 501:	learn: 0.0269338	total: 4.2s	remaining: 4.16s
# 502:	learn: 0.0269313	total: 4.21s	remaining: 4.16s
# 503:	learn: 0.0269130	total: 4.21s	remaining: 4.15s
# 504:	learn: 0.0269105	total: 4.22s	remaining: 4.14s
# 505:	learn: 0.0268912	total: 4.23s	remaining: 4.13s
# 506:	learn: 0.0268554	total: 4.24s	remaining: 4.12s
# 507:	learn: 0.0268247	total: 4.25s	remaining: 4.11s
# 508:	learn: 0.0267831	total: 4.25s	remaining: 4.1s
# 509:	learn: 0.0267687	total: 4.26s	remaining: 4.09s
# 510:	learn: 0.0267568	total: 4.27s	remaining: 4.08s
# 511:	learn: 0.0267380	total: 4.28s	remaining: 4.08s
# 512:	learn: 0.0267216	total: 4.29s	remaining: 4.07s
# 513:	learn: 0.0266618	total: 4.3s	remaining: 4.06s
# 514:	learn: 0.0266474	total: 4.3s	remaining: 4.05s
# 515:	learn: 0.0266265	total: 4.31s	remaining: 4.04s
# 516:	learn: 0.0266136	total: 4.32s	remaining: 4.04s
# 517:	learn: 0.0266051	total: 4.33s	remaining: 4.03s
# 518:	learn: 0.0265878	total: 4.33s	remaining: 4.02s
# 519:	learn: 0.0265395	total: 4.34s	remaining: 4.01s
# 520:	learn: 0.0265318	total: 4.35s	remaining: 4s
# 521:	learn: 0.0265064	total: 4.36s	remaining: 3.99s
# 522:	learn: 0.0264998	total: 4.37s	remaining: 3.98s
# 523:	learn: 0.0264831	total: 4.38s	remaining: 3.97s
# 524:	learn: 0.0264559	total: 4.38s	remaining: 3.96s
# 525:	learn: 0.0264485	total: 4.39s	remaining: 3.96s
# 526:	learn: 0.0264204	total: 4.4s	remaining: 3.95s
# 527:	learn: 0.0264129	total: 4.41s	remaining: 3.94s
# 528:	learn: 0.0263936	total: 4.41s	remaining: 3.93s
# 529:	learn: 0.0263756	total: 4.42s	remaining: 3.92s
# 530:	learn: 0.0263435	total: 4.43s	remaining: 3.91s
# 531:	learn: 0.0263160	total: 4.44s	remaining: 3.9s
# 532:	learn: 0.0262906	total: 4.45s	remaining: 3.9s
# 533:	learn: 0.0262851	total: 4.46s	remaining: 3.89s
# 534:	learn: 0.0262578	total: 4.46s	remaining: 3.88s
# 535:	learn: 0.0262380	total: 4.47s	remaining: 3.87s
# 536:	learn: 0.0262094	total: 4.48s	remaining: 3.86s
# 537:	learn: 0.0261777	total: 4.49s	remaining: 3.85s
# 538:	learn: 0.0261578	total: 4.5s	remaining: 3.85s
# 539:	learn: 0.0261332	total: 4.51s	remaining: 3.84s
# 540:	learn: 0.0261179	total: 4.51s	remaining: 3.83s
# 541:	learn: 0.0260984	total: 4.52s	remaining: 3.82s
# 542:	learn: 0.0260783	total: 4.53s	remaining: 3.81s
# 543:	learn: 0.0260685	total: 4.54s	remaining: 3.8s
# 544:	learn: 0.0260364	total: 4.55s	remaining: 3.8s
# 545:	learn: 0.0260141	total: 4.55s	remaining: 3.79s
# 546:	learn: 0.0259893	total: 4.56s	remaining: 3.78s
# 547:	learn: 0.0259640	total: 4.57s	remaining: 3.77s
# 548:	learn: 0.0259440	total: 4.58s	remaining: 3.76s
# 549:	learn: 0.0259315	total: 4.59s	remaining: 3.75s
# 550:	learn: 0.0259178	total: 4.6s	remaining: 3.75s
# 551:	learn: 0.0259085	total: 4.61s	remaining: 3.74s
# 552:	learn: 0.0258922	total: 4.61s	remaining: 3.73s
# 553:	learn: 0.0258780	total: 4.62s	remaining: 3.72s
# 554:	learn: 0.0258338	total: 4.63s	remaining: 3.71s
# 555:	learn: 0.0258005	total: 4.64s	remaining: 3.7s
# 556:	learn: 0.0257771	total: 4.65s	remaining: 3.7s
# 557:	learn: 0.0257473	total: 4.66s	remaining: 3.69s
# 558:	learn: 0.0257168	total: 4.67s	remaining: 3.68s
# 559:	learn: 0.0256561	total: 4.67s	remaining: 3.67s
# 560:	learn: 0.0256279	total: 4.68s	remaining: 3.67s
# 561:	learn: 0.0256065	total: 4.69s	remaining: 3.66s
# 562:	learn: 0.0255922	total: 4.7s	remaining: 3.65s
# 563:	learn: 0.0255693	total: 4.71s	remaining: 3.64s
# 564:	learn: 0.0255596	total: 4.72s	remaining: 3.63s
# 565:	learn: 0.0255426	total: 4.72s	remaining: 3.62s
# 566:	learn: 0.0255217	total: 4.73s	remaining: 3.61s
# 567:	learn: 0.0255129	total: 4.74s	remaining: 3.6s
# 568:	learn: 0.0254912	total: 4.75s	remaining: 3.6s
# 569:	learn: 0.0254741	total: 4.76s	remaining: 3.59s
# 570:	learn: 0.0254512	total: 4.77s	remaining: 3.58s
# 571:	learn: 0.0254427	total: 4.77s	remaining: 3.57s
# 572:	learn: 0.0254229	total: 4.78s	remaining: 3.56s
# 573:	learn: 0.0254146	total: 4.79s	remaining: 3.56s
# 574:	learn: 0.0254050	total: 4.8s	remaining: 3.55s
# 575:	learn: 0.0253903	total: 4.81s	remaining: 3.54s
# 576:	learn: 0.0253740	total: 4.82s	remaining: 3.53s
# 577:	learn: 0.0253659	total: 4.82s	remaining: 3.52s
# 578:	learn: 0.0253412	total: 4.83s	remaining: 3.51s
# 579:	learn: 0.0253234	total: 4.84s	remaining: 3.5s
# 580:	learn: 0.0253026	total: 4.85s	remaining: 3.5s
# 581:	learn: 0.0252792	total: 4.86s	remaining: 3.49s
# 582:	learn: 0.0252529	total: 4.87s	remaining: 3.48s
# 583:	learn: 0.0252415	total: 4.87s	remaining: 3.47s
# 584:	learn: 0.0252111	total: 4.88s	remaining: 3.46s
# 585:	learn: 0.0251886	total: 4.89s	remaining: 3.45s
# 586:	learn: 0.0251438	total: 4.9s	remaining: 3.45s
# 587:	learn: 0.0251301	total: 4.91s	remaining: 3.44s
# 588:	learn: 0.0250960	total: 4.92s	remaining: 3.43s
# 589:	learn: 0.0250697	total: 4.92s	remaining: 3.42s
# 590:	learn: 0.0250600	total: 4.93s	remaining: 3.41s
# 591:	learn: 0.0250451	total: 4.94s	remaining: 3.4s
# 592:	learn: 0.0250374	total: 4.95s	remaining: 3.4s
# 593:	learn: 0.0250174	total: 4.96s	remaining: 3.39s
# 594:	learn: 0.0249932	total: 4.96s	remaining: 3.38s
# 595:	learn: 0.0249653	total: 4.97s	remaining: 3.37s
# 596:	learn: 0.0249514	total: 4.98s	remaining: 3.36s
# 597:	learn: 0.0249371	total: 4.99s	remaining: 3.35s
# 598:	learn: 0.0249079	total: 5s	remaining: 3.34s
# 599:	learn: 0.0248838	total: 5s	remaining: 3.33s
# 600:	learn: 0.0248663	total: 5.01s	remaining: 3.33s
# 601:	learn: 0.0248499	total: 5.02s	remaining: 3.32s
# 602:	learn: 0.0248443	total: 5.03s	remaining: 3.31s
# 603:	learn: 0.0248063	total: 5.04s	remaining: 3.3s
# 604:	learn: 0.0247997	total: 5.04s	remaining: 3.29s
# 605:	learn: 0.0247767	total: 5.05s	remaining: 3.28s
# 606:	learn: 0.0247686	total: 5.06s	remaining: 3.27s
# 607:	learn: 0.0247575	total: 5.07s	remaining: 3.27s
# 608:	learn: 0.0247444	total: 5.07s	remaining: 3.26s
# 609:	learn: 0.0247200	total: 5.08s	remaining: 3.25s
# 610:	learn: 0.0247027	total: 5.09s	remaining: 3.24s
# 611:	learn: 0.0246848	total: 5.1s	remaining: 3.23s
# 612:	learn: 0.0246689	total: 5.11s	remaining: 3.23s
# 613:	learn: 0.0246578	total: 5.12s	remaining: 3.22s
# 614:	learn: 0.0246205	total: 5.12s	remaining: 3.21s
# 615:	learn: 0.0246027	total: 5.13s	remaining: 3.2s
# 616:	learn: 0.0245743	total: 5.14s	remaining: 3.19s
# 617:	learn: 0.0245393	total: 5.15s	remaining: 3.18s
# 618:	learn: 0.0245212	total: 5.16s	remaining: 3.17s
# 619:	learn: 0.0245150	total: 5.16s	remaining: 3.17s
# 620:	learn: 0.0244971	total: 5.17s	remaining: 3.16s
# 621:	learn: 0.0244863	total: 5.18s	remaining: 3.15s
# 622:	learn: 0.0244756	total: 5.19s	remaining: 3.14s
# 623:	learn: 0.0244526	total: 5.2s	remaining: 3.13s
# 624:	learn: 0.0244394	total: 5.21s	remaining: 3.12s
# 625:	learn: 0.0244032	total: 5.21s	remaining: 3.12s
# 626:	learn: 0.0243879	total: 5.22s	remaining: 3.11s
# 627:	learn: 0.0243771	total: 5.23s	remaining: 3.1s
# 628:	learn: 0.0243519	total: 5.24s	remaining: 3.09s
# 629:	learn: 0.0243347	total: 5.25s	remaining: 3.08s
# 630:	learn: 0.0243217	total: 5.25s	remaining: 3.07s
# 631:	learn: 0.0243138	total: 5.26s	remaining: 3.06s
# 632:	learn: 0.0242861	total: 5.27s	remaining: 3.06s
# 633:	learn: 0.0242735	total: 5.28s	remaining: 3.05s
# 634:	learn: 0.0242480	total: 5.29s	remaining: 3.04s
# 635:	learn: 0.0242260	total: 5.29s	remaining: 3.03s
# 636:	learn: 0.0242028	total: 5.3s	remaining: 3.02s
# 637:	learn: 0.0241715	total: 5.31s	remaining: 3.02s
# 638:	learn: 0.0241641	total: 5.32s	remaining: 3.01s
# 639:	learn: 0.0241357	total: 5.33s	remaining: 3s
# 640:	learn: 0.0241157	total: 5.34s	remaining: 2.99s
# 641:	learn: 0.0241010	total: 5.35s	remaining: 2.98s
# 642:	learn: 0.0240869	total: 5.36s	remaining: 2.97s
# 643:	learn: 0.0240789	total: 5.36s	remaining: 2.96s
# 644:	learn: 0.0240562	total: 5.37s	remaining: 2.96s
# 645:	learn: 0.0240445	total: 5.38s	remaining: 2.95s
# 646:	learn: 0.0240349	total: 5.39s	remaining: 2.94s
# 647:	learn: 0.0240178	total: 5.4s	remaining: 2.93s
# 648:	learn: 0.0239961	total: 5.41s	remaining: 2.92s
# 649:	learn: 0.0239635	total: 5.41s	remaining: 2.92s
# 650:	learn: 0.0239513	total: 5.42s	remaining: 2.91s
# 651:	learn: 0.0239298	total: 5.43s	remaining: 2.9s
# 652:	learn: 0.0239157	total: 5.44s	remaining: 2.89s
# 653:	learn: 0.0238962	total: 5.45s	remaining: 2.88s
# 654:	learn: 0.0238875	total: 5.45s	remaining: 2.87s
# 655:	learn: 0.0238823	total: 5.46s	remaining: 2.86s
# 656:	learn: 0.0238715	total: 5.47s	remaining: 2.85s
# 657:	learn: 0.0238606	total: 5.48s	remaining: 2.85s
# 658:	learn: 0.0238420	total: 5.49s	remaining: 2.84s
# 659:	learn: 0.0238271	total: 5.5s	remaining: 2.83s
# 660:	learn: 0.0238128	total: 5.5s	remaining: 2.82s
# 661:	learn: 0.0238116	total: 5.51s	remaining: 2.81s
# 662:	learn: 0.0237945	total: 5.52s	remaining: 2.81s
# 663:	learn: 0.0237862	total: 5.53s	remaining: 2.8s
# 664:	learn: 0.0237631	total: 5.54s	remaining: 2.79s
# 665:	learn: 0.0237482	total: 5.54s	remaining: 2.78s
# 666:	learn: 0.0237401	total: 5.55s	remaining: 2.77s
# 667:	learn: 0.0237201	total: 5.56s	remaining: 2.76s
# 668:	learn: 0.0237115	total: 5.57s	remaining: 2.75s
# 669:	learn: 0.0237060	total: 5.58s	remaining: 2.75s
# 670:	learn: 0.0236988	total: 5.58s	remaining: 2.74s
# 671:	learn: 0.0236965	total: 5.59s	remaining: 2.73s
# 672:	learn: 0.0236805	total: 5.6s	remaining: 2.72s
# 673:	learn: 0.0236526	total: 5.61s	remaining: 2.71s
# 674:	learn: 0.0236367	total: 5.62s	remaining: 2.7s
# 675:	learn: 0.0236256	total: 5.62s	remaining: 2.69s
# 676:	learn: 0.0236137	total: 5.63s	remaining: 2.69s
# 677:	learn: 0.0235958	total: 5.64s	remaining: 2.68s
# 678:	learn: 0.0235831	total: 5.65s	remaining: 2.67s
# 679:	learn: 0.0235755	total: 5.66s	remaining: 2.66s
# 680:	learn: 0.0235558	total: 5.67s	remaining: 2.65s
# 681:	learn: 0.0235335	total: 5.67s	remaining: 2.65s
# 682:	learn: 0.0235253	total: 5.68s	remaining: 2.64s
# 683:	learn: 0.0235073	total: 5.69s	remaining: 2.63s
# 684:	learn: 0.0234796	total: 5.7s	remaining: 2.62s
# 685:	learn: 0.0234669	total: 5.71s	remaining: 2.61s
# 686:	learn: 0.0234359	total: 5.72s	remaining: 2.6s
# 687:	learn: 0.0234283	total: 5.72s	remaining: 2.6s
# 688:	learn: 0.0234182	total: 5.73s	remaining: 2.59s
# 689:	learn: 0.0234043	total: 5.74s	remaining: 2.58s
# 690:	learn: 0.0233801	total: 5.75s	remaining: 2.57s
# 691:	learn: 0.0233547	total: 5.76s	remaining: 2.56s
# 692:	learn: 0.0233472	total: 5.76s	remaining: 2.55s
# 693:	learn: 0.0233220	total: 5.77s	remaining: 2.54s
# 694:	learn: 0.0233047	total: 5.78s	remaining: 2.54s
# 695:	learn: 0.0232946	total: 5.79s	remaining: 2.53s
# 696:	learn: 0.0232661	total: 5.8s	remaining: 2.52s
# 697:	learn: 0.0232548	total: 5.8s	remaining: 2.51s
# 698:	learn: 0.0232341	total: 5.82s	remaining: 2.5s
# 699:	learn: 0.0232292	total: 5.82s	remaining: 2.5s
# 700:	learn: 0.0232130	total: 5.83s	remaining: 2.49s
# 701:	learn: 0.0231954	total: 5.84s	remaining: 2.48s
# 702:	learn: 0.0231781	total: 5.85s	remaining: 2.47s
# 703:	learn: 0.0231713	total: 5.86s	remaining: 2.46s
# 704:	learn: 0.0231659	total: 5.86s	remaining: 2.45s
# 705:	learn: 0.0231499	total: 5.87s	remaining: 2.44s
# 706:	learn: 0.0231348	total: 5.88s	remaining: 2.44s
# 707:	learn: 0.0231033	total: 5.89s	remaining: 2.43s
# 708:	learn: 0.0230963	total: 5.89s	remaining: 2.42s
# 709:	learn: 0.0230855	total: 5.9s	remaining: 2.41s
# 710:	learn: 0.0230718	total: 5.91s	remaining: 2.4s
# 711:	learn: 0.0230608	total: 5.92s	remaining: 2.39s
# 712:	learn: 0.0230472	total: 5.93s	remaining: 2.38s
# 713:	learn: 0.0230309	total: 5.93s	remaining: 2.38s
# 714:	learn: 0.0230244	total: 5.94s	remaining: 2.37s
# 715:	learn: 0.0230195	total: 5.95s	remaining: 2.36s
# 716:	learn: 0.0229995	total: 5.96s	remaining: 2.35s
# 717:	learn: 0.0229706	total: 5.97s	remaining: 2.34s
# 718:	learn: 0.0229305	total: 5.98s	remaining: 2.33s
# 719:	learn: 0.0229189	total: 5.98s	remaining: 2.33s
# 720:	learn: 0.0229044	total: 5.99s	remaining: 2.32s
# 721:	learn: 0.0228924	total: 6s	remaining: 2.31s
# 722:	learn: 0.0228715	total: 6.01s	remaining: 2.3s
# 723:	learn: 0.0228497	total: 6.02s	remaining: 2.29s
# 724:	learn: 0.0228309	total: 6.02s	remaining: 2.29s
# 725:	learn: 0.0228259	total: 6.03s	remaining: 2.28s
# 726:	learn: 0.0228187	total: 6.04s	remaining: 2.27s
# 727:	learn: 0.0228080	total: 6.05s	remaining: 2.26s
# 728:	learn: 0.0227979	total: 6.05s	remaining: 2.25s
# 729:	learn: 0.0227939	total: 6.06s	remaining: 2.24s
# 730:	learn: 0.0227765	total: 6.07s	remaining: 2.23s
# 731:	learn: 0.0227506	total: 6.08s	remaining: 2.23s
# 732:	learn: 0.0227306	total: 6.09s	remaining: 2.22s
# 733:	learn: 0.0226965	total: 6.1s	remaining: 2.21s
# 734:	learn: 0.0226780	total: 6.1s	remaining: 2.2s
# 735:	learn: 0.0226621	total: 6.11s	remaining: 2.19s
# 736:	learn: 0.0226421	total: 6.12s	remaining: 2.18s
# 737:	learn: 0.0226322	total: 6.13s	remaining: 2.18s
# 738:	learn: 0.0226181	total: 6.14s	remaining: 2.17s
# 739:	learn: 0.0226008	total: 6.14s	remaining: 2.16s
# 740:	learn: 0.0225904	total: 6.15s	remaining: 2.15s
# 741:	learn: 0.0225732	total: 6.16s	remaining: 2.14s
# 742:	learn: 0.0225573	total: 6.17s	remaining: 2.13s
# 743:	learn: 0.0225376	total: 6.18s	remaining: 2.13s
# 744:	learn: 0.0225218	total: 6.19s	remaining: 2.12s
# 745:	learn: 0.0224945	total: 6.2s	remaining: 2.11s
# 746:	learn: 0.0224874	total: 6.2s	remaining: 2.1s
# 747:	learn: 0.0224844	total: 6.21s	remaining: 2.09s
# 748:	learn: 0.0224650	total: 6.22s	remaining: 2.08s
# 749:	learn: 0.0224543	total: 6.23s	remaining: 2.08s
# 750:	learn: 0.0224404	total: 6.24s	remaining: 2.07s
# 751:	learn: 0.0224324	total: 6.24s	remaining: 2.06s
# 752:	learn: 0.0224203	total: 6.25s	remaining: 2.05s
# 753:	learn: 0.0224051	total: 6.26s	remaining: 2.04s
# 754:	learn: 0.0223932	total: 6.27s	remaining: 2.03s
# 755:	learn: 0.0223788	total: 6.27s	remaining: 2.02s
# 756:	learn: 0.0223726	total: 6.28s	remaining: 2.02s
# 757:	learn: 0.0223569	total: 6.29s	remaining: 2.01s
# 758:	learn: 0.0223554	total: 6.3s	remaining: 2s
# 759:	learn: 0.0223463	total: 6.31s	remaining: 1.99s
# 760:	learn: 0.0223290	total: 6.32s	remaining: 1.98s
# 761:	learn: 0.0223220	total: 6.32s	remaining: 1.98s
# 762:	learn: 0.0223135	total: 6.33s	remaining: 1.97s
# 763:	learn: 0.0223049	total: 6.34s	remaining: 1.96s
# 764:	learn: 0.0222981	total: 6.35s	remaining: 1.95s
# 765:	learn: 0.0222739	total: 6.35s	remaining: 1.94s
# 766:	learn: 0.0222556	total: 6.36s	remaining: 1.93s
# 767:	learn: 0.0222475	total: 6.37s	remaining: 1.92s
# 768:	learn: 0.0222394	total: 6.38s	remaining: 1.92s
# 769:	learn: 0.0222330	total: 6.38s	remaining: 1.91s
# 770:	learn: 0.0222259	total: 6.39s	remaining: 1.9s
# 771:	learn: 0.0222042	total: 6.4s	remaining: 1.89s
# 772:	learn: 0.0221791	total: 6.41s	remaining: 1.88s
# 773:	learn: 0.0221705	total: 6.42s	remaining: 1.87s
# 774:	learn: 0.0221693	total: 6.42s	remaining: 1.86s
# 775:	learn: 0.0221651	total: 6.43s	remaining: 1.86s
# 776:	learn: 0.0221543	total: 6.44s	remaining: 1.85s
# 777:	learn: 0.0221447	total: 6.45s	remaining: 1.84s
# 778:	learn: 0.0221336	total: 6.45s	remaining: 1.83s
# 779:	learn: 0.0221283	total: 6.46s	remaining: 1.82s
# 780:	learn: 0.0221082	total: 6.47s	remaining: 1.81s
# 781:	learn: 0.0220833	total: 6.48s	remaining: 1.81s
# 782:	learn: 0.0220693	total: 6.49s	remaining: 1.8s
# 783:	learn: 0.0220608	total: 6.5s	remaining: 1.79s
# 784:	learn: 0.0220478	total: 6.5s	remaining: 1.78s
# 785:	learn: 0.0220434	total: 6.51s	remaining: 1.77s
# 786:	learn: 0.0220405	total: 6.52s	remaining: 1.76s
# 787:	learn: 0.0220276	total: 6.53s	remaining: 1.76s
# 788:	learn: 0.0220073	total: 6.54s	remaining: 1.75s
# 789:	learn: 0.0219958	total: 6.54s	remaining: 1.74s
# 790:	learn: 0.0219857	total: 6.55s	remaining: 1.73s
# 791:	learn: 0.0219612	total: 6.56s	remaining: 1.72s
# 792:	learn: 0.0219474	total: 6.57s	remaining: 1.71s
# 793:	learn: 0.0219384	total: 6.58s	remaining: 1.71s
# 794:	learn: 0.0219101	total: 6.59s	remaining: 1.7s
# 795:	learn: 0.0218852	total: 6.59s	remaining: 1.69s
# 796:	learn: 0.0218731	total: 6.6s	remaining: 1.68s
# 797:	learn: 0.0218713	total: 6.61s	remaining: 1.67s
# 798:	learn: 0.0218463	total: 6.62s	remaining: 1.67s
# 799:	learn: 0.0218337	total: 6.63s	remaining: 1.66s
# 800:	learn: 0.0218274	total: 6.63s	remaining: 1.65s
# 801:	learn: 0.0218180	total: 6.64s	remaining: 1.64s
# 802:	learn: 0.0218033	total: 6.65s	remaining: 1.63s
# 803:	learn: 0.0217955	total: 6.66s	remaining: 1.62s
# 804:	learn: 0.0217828	total: 6.67s	remaining: 1.61s
# 805:	learn: 0.0217759	total: 6.67s	remaining: 1.61s
# 806:	learn: 0.0217602	total: 6.68s	remaining: 1.6s
# 807:	learn: 0.0217457	total: 6.69s	remaining: 1.59s
# 808:	learn: 0.0217158	total: 6.7s	remaining: 1.58s
# 809:	learn: 0.0216929	total: 6.71s	remaining: 1.57s
# 810:	learn: 0.0216872	total: 6.72s	remaining: 1.56s
# 811:	learn: 0.0216598	total: 6.73s	remaining: 1.56s
# 812:	learn: 0.0216385	total: 6.73s	remaining: 1.55s
# 813:	learn: 0.0216213	total: 6.74s	remaining: 1.54s
# 814:	learn: 0.0216056	total: 6.75s	remaining: 1.53s
# 815:	learn: 0.0215791	total: 6.76s	remaining: 1.52s
# 816:	learn: 0.0215663	total: 6.77s	remaining: 1.51s
# 817:	learn: 0.0215486	total: 6.78s	remaining: 1.51s
# 818:	learn: 0.0215402	total: 6.78s	remaining: 1.5s
# 819:	learn: 0.0215245	total: 6.79s	remaining: 1.49s
# 820:	learn: 0.0215183	total: 6.8s	remaining: 1.48s
# 821:	learn: 0.0215027	total: 6.81s	remaining: 1.47s
# 822:	learn: 0.0214969	total: 6.82s	remaining: 1.47s
# 823:	learn: 0.0214926	total: 6.82s	remaining: 1.46s
# 824:	learn: 0.0214784	total: 6.83s	remaining: 1.45s
# 825:	learn: 0.0214644	total: 6.84s	remaining: 1.44s
# 826:	learn: 0.0214575	total: 6.85s	remaining: 1.43s
# 827:	learn: 0.0214440	total: 6.86s	remaining: 1.42s
# 828:	learn: 0.0214413	total: 6.87s	remaining: 1.42s
# 829:	learn: 0.0214361	total: 6.87s	remaining: 1.41s
# 830:	learn: 0.0214116	total: 6.88s	remaining: 1.4s
# 831:	learn: 0.0214062	total: 6.89s	remaining: 1.39s
# 832:	learn: 0.0213942	total: 6.9s	remaining: 1.38s
# 833:	learn: 0.0213794	total: 6.9s	remaining: 1.37s
# 834:	learn: 0.0213620	total: 6.91s	remaining: 1.37s
# 835:	learn: 0.0213394	total: 6.92s	remaining: 1.36s
# 836:	learn: 0.0213263	total: 6.93s	remaining: 1.35s
# 837:	learn: 0.0213155	total: 6.94s	remaining: 1.34s
# 838:	learn: 0.0213026	total: 6.95s	remaining: 1.33s
# 839:	learn: 0.0212896	total: 6.96s	remaining: 1.32s
# 840:	learn: 0.0212626	total: 6.96s	remaining: 1.32s
# 841:	learn: 0.0212541	total: 6.97s	remaining: 1.31s
# 842:	learn: 0.0212496	total: 6.98s	remaining: 1.3s
# 843:	learn: 0.0212194	total: 6.99s	remaining: 1.29s
# 844:	learn: 0.0212053	total: 7s	remaining: 1.28s
# 845:	learn: 0.0211778	total: 7s	remaining: 1.27s
# 846:	learn: 0.0211649	total: 7.01s	remaining: 1.27s
# 847:	learn: 0.0211517	total: 7.02s	remaining: 1.26s
# 848:	learn: 0.0211417	total: 7.03s	remaining: 1.25s
# 849:	learn: 0.0211120	total: 7.04s	remaining: 1.24s
# 850:	learn: 0.0211004	total: 7.05s	remaining: 1.23s
# 851:	learn: 0.0210889	total: 7.05s	remaining: 1.23s
# 852:	learn: 0.0210603	total: 7.06s	remaining: 1.22s
# 853:	learn: 0.0210531	total: 7.07s	remaining: 1.21s
# 854:	learn: 0.0210432	total: 7.08s	remaining: 1.2s
# 855:	learn: 0.0210329	total: 7.09s	remaining: 1.19s
# 856:	learn: 0.0210283	total: 7.09s	remaining: 1.18s
# 857:	learn: 0.0210220	total: 7.1s	remaining: 1.18s
# 858:	learn: 0.0210060	total: 7.11s	remaining: 1.17s
# 859:	learn: 0.0209970	total: 7.12s	remaining: 1.16s
# 860:	learn: 0.0209904	total: 7.13s	remaining: 1.15s
# 861:	learn: 0.0209833	total: 7.14s	remaining: 1.14s
# 862:	learn: 0.0209755	total: 7.14s	remaining: 1.13s
# 863:	learn: 0.0209517	total: 7.15s	remaining: 1.13s
# 864:	learn: 0.0209421	total: 7.16s	remaining: 1.12s
# 865:	learn: 0.0209378	total: 7.17s	remaining: 1.11s
# 866:	learn: 0.0209076	total: 7.18s	remaining: 1.1s
# 867:	learn: 0.0209030	total: 7.19s	remaining: 1.09s
# 868:	learn: 0.0208917	total: 7.2s	remaining: 1.08s
# 869:	learn: 0.0208818	total: 7.2s	remaining: 1.08s
# 870:	learn: 0.0208672	total: 7.21s	remaining: 1.07s
# 871:	learn: 0.0208549	total: 7.22s	remaining: 1.06s
# 872:	learn: 0.0208452	total: 7.23s	remaining: 1.05s
# 873:	learn: 0.0208317	total: 7.24s	remaining: 1.04s
# 874:	learn: 0.0208168	total: 7.25s	remaining: 1.03s
# 875:	learn: 0.0208136	total: 7.25s	remaining: 1.03s
# 876:	learn: 0.0207990	total: 7.26s	remaining: 1.02s
# 877:	learn: 0.0207964	total: 7.27s	remaining: 1.01s
# 878:	learn: 0.0207803	total: 7.28s	remaining: 1s
# 879:	learn: 0.0207494	total: 7.29s	remaining: 994ms
# 880:	learn: 0.0207317	total: 7.29s	remaining: 985ms
# 881:	learn: 0.0207249	total: 7.3s	remaining: 977ms
# 882:	learn: 0.0207097	total: 7.31s	remaining: 969ms
# 883:	learn: 0.0207011	total: 7.32s	remaining: 960ms
# 884:	learn: 0.0206939	total: 7.32s	remaining: 952ms
# 885:	learn: 0.0206827	total: 7.33s	remaining: 944ms
# 886:	learn: 0.0206717	total: 7.34s	remaining: 935ms
# 887:	learn: 0.0206652	total: 7.35s	remaining: 927ms
# 888:	learn: 0.0206547	total: 7.36s	remaining: 919ms
# 889:	learn: 0.0206413	total: 7.36s	remaining: 910ms
# 890:	learn: 0.0206309	total: 7.37s	remaining: 902ms
# 891:	learn: 0.0206023	total: 7.38s	remaining: 894ms
# 892:	learn: 0.0205881	total: 7.39s	remaining: 885ms
# 893:	learn: 0.0205772	total: 7.4s	remaining: 877ms
# 894:	learn: 0.0205634	total: 7.41s	remaining: 869ms
# 895:	learn: 0.0205373	total: 7.42s	remaining: 861ms
# 896:	learn: 0.0205159	total: 7.42s	remaining: 853ms
# 897:	learn: 0.0205128	total: 7.43s	remaining: 844ms
# 898:	learn: 0.0204918	total: 7.44s	remaining: 836ms
# 899:	learn: 0.0204777	total: 7.45s	remaining: 828ms
# 900:	learn: 0.0204687	total: 7.46s	remaining: 820ms
# 901:	learn: 0.0204552	total: 7.47s	remaining: 811ms
# 902:	learn: 0.0204302	total: 7.48s	remaining: 803ms
# 903:	learn: 0.0204197	total: 7.48s	remaining: 795ms
# 904:	learn: 0.0204029	total: 7.49s	remaining: 787ms
# 905:	learn: 0.0203904	total: 7.5s	remaining: 778ms
# 906:	learn: 0.0203627	total: 7.51s	remaining: 770ms
# 907:	learn: 0.0203431	total: 7.52s	remaining: 762ms
# 908:	learn: 0.0203400	total: 7.53s	remaining: 754ms
# 909:	learn: 0.0203162	total: 7.54s	remaining: 745ms
# 910:	learn: 0.0203015	total: 7.54s	remaining: 737ms
# 911:	learn: 0.0202858	total: 7.55s	remaining: 729ms
# 912:	learn: 0.0202825	total: 7.56s	remaining: 721ms
# 913:	learn: 0.0202594	total: 7.57s	remaining: 712ms
# 914:	learn: 0.0202543	total: 7.58s	remaining: 704ms
# 915:	learn: 0.0202413	total: 7.59s	remaining: 696ms
# 916:	learn: 0.0202349	total: 7.59s	remaining: 687ms
# 917:	learn: 0.0202296	total: 7.6s	remaining: 679ms
# 918:	learn: 0.0202182	total: 7.61s	remaining: 671ms
# 919:	learn: 0.0202099	total: 7.62s	remaining: 663ms
# 920:	learn: 0.0201994	total: 7.63s	remaining: 654ms
# 921:	learn: 0.0201775	total: 7.63s	remaining: 646ms
# 922:	learn: 0.0201765	total: 7.64s	remaining: 638ms
# 923:	learn: 0.0201634	total: 7.65s	remaining: 629ms
# 924:	learn: 0.0201569	total: 7.66s	remaining: 621ms
# 925:	learn: 0.0201370	total: 7.67s	remaining: 613ms
# 926:	learn: 0.0201332	total: 7.67s	remaining: 604ms
# 927:	learn: 0.0201235	total: 7.68s	remaining: 596ms
# 928:	learn: 0.0201129	total: 7.69s	remaining: 588ms
# 929:	learn: 0.0200863	total: 7.7s	remaining: 580ms
# 930:	learn: 0.0200632	total: 7.71s	remaining: 571ms
# 931:	learn: 0.0200404	total: 7.72s	remaining: 563ms
# 932:	learn: 0.0200269	total: 7.72s	remaining: 555ms
# 933:	learn: 0.0200158	total: 7.73s	remaining: 546ms
# 934:	learn: 0.0200087	total: 7.74s	remaining: 538ms
# 935:	learn: 0.0199988	total: 7.75s	remaining: 530ms
# 936:	learn: 0.0199689	total: 7.76s	remaining: 522ms
# 937:	learn: 0.0199642	total: 7.76s	remaining: 513ms
# 938:	learn: 0.0199582	total: 7.77s	remaining: 505ms
# 939:	learn: 0.0199095	total: 7.78s	remaining: 497ms
# 940:	learn: 0.0199020	total: 7.79s	remaining: 488ms
# 941:	learn: 0.0198855	total: 7.8s	remaining: 480ms
# 942:	learn: 0.0198649	total: 7.81s	remaining: 472ms
# 943:	learn: 0.0198536	total: 7.82s	remaining: 464ms
# 944:	learn: 0.0198520	total: 7.82s	remaining: 455ms
# 945:	learn: 0.0198438	total: 7.83s	remaining: 447ms
# 946:	learn: 0.0198362	total: 7.84s	remaining: 439ms
# 947:	learn: 0.0198309	total: 7.84s	remaining: 430ms
# 948:	learn: 0.0198288	total: 7.85s	remaining: 422ms
# 949:	learn: 0.0198261	total: 7.86s	remaining: 414ms
# 950:	learn: 0.0198115	total: 7.87s	remaining: 406ms
# 951:	learn: 0.0197990	total: 7.88s	remaining: 397ms
# 952:	learn: 0.0197888	total: 7.89s	remaining: 389ms
# 953:	learn: 0.0197654	total: 7.9s	remaining: 381ms
# 954:	learn: 0.0197592	total: 7.9s	remaining: 372ms
# 955:	learn: 0.0197541	total: 7.91s	remaining: 364ms
# 956:	learn: 0.0197482	total: 7.92s	remaining: 356ms
# 957:	learn: 0.0197308	total: 7.93s	remaining: 348ms
# 958:	learn: 0.0197122	total: 7.93s	remaining: 339ms
# 959:	learn: 0.0197097	total: 7.94s	remaining: 331ms
# 960:	learn: 0.0197028	total: 7.95s	remaining: 323ms
# 961:	learn: 0.0196898	total: 7.96s	remaining: 314ms
# 962:	learn: 0.0196798	total: 7.97s	remaining: 306ms
# 963:	learn: 0.0196563	total: 7.98s	remaining: 298ms
# 964:	learn: 0.0196471	total: 7.99s	remaining: 290ms
# 965:	learn: 0.0196247	total: 7.99s	remaining: 281ms
# 966:	learn: 0.0196185	total: 8s	remaining: 273ms
# 967:	learn: 0.0196009	total: 8.01s	remaining: 265ms
# 968:	learn: 0.0195802	total: 8.02s	remaining: 257ms
# 969:	learn: 0.0195729	total: 8.03s	remaining: 248ms
# 970:	learn: 0.0195521	total: 8.04s	remaining: 240ms
# 971:	learn: 0.0195428	total: 8.05s	remaining: 232ms
# 972:	learn: 0.0195289	total: 8.05s	remaining: 224ms
# 973:	learn: 0.0195158	total: 8.06s	remaining: 215ms
# 974:	learn: 0.0195130	total: 8.07s	remaining: 207ms
# 975:	learn: 0.0195013	total: 8.08s	remaining: 199ms
# 976:	learn: 0.0194927	total: 8.09s	remaining: 190ms
# 977:	learn: 0.0194841	total: 8.1s	remaining: 182ms
# 978:	learn: 0.0194624	total: 8.1s	remaining: 174ms
# 979:	learn: 0.0194577	total: 8.11s	remaining: 166ms
# 980:	learn: 0.0194447	total: 8.12s	remaining: 157ms
# 981:	learn: 0.0194380	total: 8.13s	remaining: 149ms
# 982:	learn: 0.0194219	total: 8.13s	remaining: 141ms
# 983:	learn: 0.0194048	total: 8.14s	remaining: 132ms
# 984:	learn: 0.0193970	total: 8.15s	remaining: 124ms
# 985:	learn: 0.0193897	total: 8.16s	remaining: 116ms
# 986:	learn: 0.0193724	total: 8.17s	remaining: 108ms
# 987:	learn: 0.0193526	total: 8.18s	remaining: 99.3ms
# 988:	learn: 0.0193431	total: 8.19s	remaining: 91ms
# 989:	learn: 0.0193313	total: 8.19s	remaining: 82.8ms
# 990:	learn: 0.0193301	total: 8.2s	remaining: 74.5ms
# 991:	learn: 0.0193275	total: 8.21s	remaining: 66.2ms
# 992:	learn: 0.0193241	total: 8.22s	remaining: 57.9ms
# 993:	learn: 0.0193126	total: 8.22s	remaining: 49.6ms
# 994:	learn: 0.0193089	total: 8.23s	remaining: 41.4ms
# 995:	learn: 0.0193022	total: 8.24s	remaining: 33.1ms
# 996:	learn: 0.0193001	total: 8.25s	remaining: 24.8ms
# 997:	learn: 0.0192857	total: 8.26s	remaining: 16.5ms
# 998:	learn: 0.0192730	total: 8.26s	remaining: 8.27ms
# 999:	learn: 0.0192624	total: 8.27s	remaining: 0us
# 2486

# %%
preds1
# Out:
# array([[0., 1., 1., ..., 0., 1., 0.]])

# %%
preds2
# Out:
# array([[1, 1, 0, ..., 0, 1, 1]])

# %%
preds3
# Out:
# array([[1, 1, 1, ..., 0, 1, 1]])

# %%
preds4
# Out:
# array([[1, 1, 0, ..., 0, 1, 1]])

# %%
final_prediction
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
# seed(3)에 대해서만 제출 할 때 
sub=pd.read_csv('submission.csv')
sub['is_converted']= final_prediction
sub.to_csv('submission.csv',index= False)
# sub.to_csv('0224_nofe2_proba002_seed_ensemble.csv',index=False)
