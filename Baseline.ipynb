# %% [markdown]
# # 영업 성공 여부 분류 경진대회

# %% [markdown]
# ## 1. 데이터 확인

# %% [markdown]
# ### 필수 라이브러리

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
import random
import os

def seed_everything(seed=42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    
seed_everything()

# %% [markdown]
# ### 데이터 셋 읽어오기

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
df_train.head() # 학습용 데이터 살펴보기
# Out:
#    bant_submit          customer_country business_unit  com_reg_ver_win_rate  \
# 0          1.0  /Quezon City/Philippines            AS              0.066667
# 1          1.0        /PH-00/Philippines            AS              0.066667
# 2          1.0           /Kolkata /India            AS              0.088889
# 3          1.0        /Bhubaneswar/India            AS              0.088889
# 4          1.0          /Hyderabad/India            AS              0.088889
#
#    customer_idx          customer_type  enterprise  historical_existing_cnt  \
# 0         32160           End-Customer  Enterprise                      NaN
# 1         23122           End-Customer  Enterprise                     12.0
# 2          1755           End-Customer  Enterprise                    144.0
# 3          4919           End-Customer  Enterprise                      NaN
# 4         17126  Specifier/ Influencer  Enterprise                      NaN
#
#    id_strategic_ver  it_strategic_ver  ...  response_corporate  \
# 0               NaN               NaN  ...               LGEPH
# 1               NaN               NaN  ...               LGEPH
# 2               NaN               NaN  ...               LGEIL
# 3               NaN               NaN  ...               LGEIL
# 4               NaN               NaN  ...               LGEIL
#
#     expected_timeline  ver_cus ver_pro ver_win_rate_x ver_win_ratio_per_bu  \
# 0  less than 3 months        1       0       0.003079             0.026846
# 1  less than 3 months        1       0       0.003079             0.026846
# 2  less than 3 months        1       0       0.003079             0.026846
# 3  less than 3 months        1       0       0.003079             0.026846
# 4  less than 3 months        0       0       0.003079             0.026846
#
#         business_area business_subarea lead_owner is_converted
# 0  corporate / office      Engineering          0         True
# 1  corporate / office      Advertising          1         True
# 2  corporate / office     Construction          2         True
# 3  corporate / office      IT/Software          3         True
# 4  corporate / office              NaN          4         True
#
# [5 rows x 29 columns]

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# ### 레이블 인코딩

# %%
def label_encoding(series: pd.Series) -> pd.Series:
    """범주형 데이터를 시리즈 형태로 받아 숫자형 데이터로 변환합니다."""

    my_dict = {}

    # 모든 요소를 문자열로 변환
    series = series.astype(str)

    for idx, value in enumerate(sorted(series.unique())):
        my_dict[value] = idx
    series = series.map(my_dict)

    return series

# %%
# 레이블 인코딩할 칼럼들
label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_country.1",
    "customer_position",
    "response_corporate",
    "expected_timeline",
]

df_all = pd.concat([df_train[label_columns], df_test[label_columns]])

for col in label_columns:
    df_all[col] = label_encoding(df_all[col])

# %% [markdown]
# 다시 학습 데이터와 제출 데이터를 분리합니다.

# %%
for col in label_columns:  
    df_train[col] = df_all.iloc[: len(df_train)][col]
    df_test[col] = df_all.iloc[len(df_train) :][col]

# %% [markdown]
# ### 2-2. 학습, 검증 데이터 분리

# %%
X = df_train.drop("is_converted", axis=1).fillna(0)
y = df_train["is_converted"]

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X,
    y,
    test_size=0.2,
    shuffle=True,
    random_state=42,
)

# %%
x_train
# Out:
#        bant_submit  customer_country  business_unit  com_reg_ver_win_rate  \
# 19499         0.25               165              0              0.000000
# 5354          1.00              2749              2              0.000000
# 35027         0.50              1869              2              0.000000
# 22417         1.00              3109              0              0.048544
# 48416         0.50              1927              3              0.000000
# ...            ...               ...            ...                   ...
# 54343         1.00             11043              2              0.269231
# 38158         0.50              3160              0              0.000000
# 860           0.75              3388              2              0.057534
# 15795         0.50             11717              0              0.000000
# 56422         1.00             11210              2              0.073248
#
#        customer_idx  customer_type  enterprise  historical_existing_cnt  \
# 19499         47466              9           0                     19.0
# 5354          47466             33           0                      4.0
# 35027         19504             33           0                      0.0
# 22417          1944             33           0                      0.0
# 48416         27783             33           1                      0.0
# ...             ...            ...         ...                      ...
# 54343          7798             10           1                      0.0
# 38158          5937             33           0                      0.0
# 860           37179             33           1                      0.0
# 15795          4372             33           1                      0.0
# 56422         19006             33           0                      0.0
#
#        id_strategic_ver  it_strategic_ver  ...  customer_position  \
# 19499               0.0               0.0  ...                 74
# 5354                0.0               0.0  ...                 21
# 35027               0.0               0.0  ...                 74
# 22417               0.0               0.0  ...                 21
# 48416               0.0               0.0  ...                 74
# ...                 ...               ...  ...                ...
# 54343               0.0               0.0  ...                 21
# 38158               0.0               0.0  ...                 47
# 860                 1.0               0.0  ...                 21
# 15795               0.0               0.0  ...                 64
# 56422               0.0               0.0  ...                 36
#
#        response_corporate  expected_timeline  ver_cus  ver_pro  \
# 19499                  21                271        0        0
# 5354                   21                  8        0        0
# 35027                  50                267        0        0
# 22417                  18                246        0        0
# 48416                  12                271        0        0
# ...                   ...                ...      ...      ...
# 54343                   7                246        0        0
# 38158                  43                271        0        0
# 860                    21                246        0        0
# 15795                  14                271        0        0
# 56422                  43                246        0        1
#
#        ver_win_rate_x  ver_win_ratio_per_bu  business_area  business_subarea  \
# 19499        0.000000              0.000000              6                86
# 5354         0.000000              0.000000              6                86
# 35027        0.000000              0.000000              6                86
# 22417        0.000543              0.022634             11                86
# 48416        0.000000              0.000000              6                86
# ...               ...                   ...            ...               ...
# 54343        0.000060              0.131148              4                16
# 38158        0.000000              0.000000              6                86
# 860          0.003079              0.064566              0                86
# 15795        0.000000              0.000000              6                86
# 56422        0.001183              0.049840             10                86
#
#        lead_owner
# 19499         115
# 5354          175
# 35027         194
# 22417          68
# 48416         980
# ...           ...
# 54343         344
# 38158          23
# 860           174
# 15795          62
# 56422         167
#
# [47439 rows x 28 columns]

# %%
x_val
# Out:
#        bant_submit  customer_country  business_unit  com_reg_ver_win_rate  \
# 37178         0.25              2005              0              0.000000
# 6990          1.00              6075              2              0.000000
# 21789         1.00              2501              2              0.043103
# 2152          1.00              7838              2              0.000000
# 23825         1.00              2036              2              0.000000
# ...            ...               ...            ...                   ...
# 8850          0.75              9788              2              0.000000
# 35738         0.50              6108              0              0.000000
# 26894         0.25             17351              2              0.124122
# 57604         1.00              9183              0              0.004000
# 44446         0.75              2769              0              0.000000
#
#        customer_idx  customer_type  enterprise  historical_existing_cnt  \
# 37178         21752             33           1                      1.0
# 6990          27412             33           0                      0.0
# 21789         36483             33           0                      0.0
# 2152          25096             33           0                      0.0
# 23825         25219              9           0                      0.0
# ...             ...            ...         ...                      ...
# 8850          47466             33           0                      4.0
# 35738         25096             33           0                      0.0
# 26894         10630              9           1                      0.0
# 57604         12473             29           1                      1.0
# 44446         16965             33           0                      0.0
#
#        id_strategic_ver  it_strategic_ver  ...  customer_position  \
# 37178               0.0               0.0  ...                 74
# 6990                0.0               0.0  ...                 36
# 21789               0.0               0.0  ...                 80
# 2152                0.0               0.0  ...                 21
# 23825               0.0               0.0  ...                 21
# ...                 ...               ...  ...                ...
# 8850                0.0               0.0  ...                 21
# 35738               0.0               0.0  ...                 21
# 26894               1.0               0.0  ...                 64
# 57604               0.0               0.0  ...                 36
# 44446               0.0               0.0  ...                 21
#
#        response_corporate  expected_timeline  ver_cus  ver_pro  \
# 37178                  33                271        0        0
# 6990                   21                246        0        0
# 21789                  15                246        0        0
# 2152                   21                246        0        0
# 23825                  46                246        0        0
# ...                   ...                ...      ...      ...
# 8850                   21                  8        0        0
# 35738                  21                271        0        0
# 26894                  43                271        1        0
# 57604                  43                267        0        0
# 44446                  10                271        0        0
#
#        ver_win_rate_x  ver_win_ratio_per_bu  business_area  business_subarea  \
# 37178        0.000000              0.000000              6                86
# 6990         0.000000              0.000000              6                86
# 21789        0.000543              0.064070             11                86
# 2152         0.000000              0.000000              6                86
# 23825        0.000060              0.131148              4                16
# ...               ...                   ...            ...               ...
# 8850         0.000000              0.000000              6                86
# 35738        0.000000              0.000000              6                86
# 26894        0.000717              0.071345              5                74
# 57604        0.001183              0.011583             10                86
# 44446        0.000000              0.000000              6                86
#
#        lead_owner
# 37178           1
# 6990          174
# 21789         234
# 2152          164
# 23825         285
# ...           ...
# 8850          164
# 35738          48
# 26894         487
# 57604          97
# 44446         100
#
# [11860 rows x 28 columns]

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
model = DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ### 모델 학습

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ### 모델 성능 보기

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = confusion_matrix(y_test, y_pred, labels=[True, False])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
pred = model.predict(x_val)
get_clf_eval(y_val, pred)
# Out:
# 오차행렬:
#  [[  779   206]
#  [  221 10654]]
#
# 정확도: 0.9640
# 정밀도: 0.7790
# 재현율: 0.7909
# F1: 0.7849

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 테스트 데이터 예측

# %%
model.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# 예측에 필요한 데이터 분리
x_test = df_test.drop(["is_converted", "id"], axis=1).fillna(0)

# %%
test_pred = model.predict(x_test)
sum(test_pred) # True로 예측된 개수
# Out:
# 1335

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission_original.csv")
df_sub["is_converted"] = test_pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %%
df_sub["is_converted"].value_counts()
# Out:
# False    3936
# True     1335
# Name: is_converted, dtype: int64

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
